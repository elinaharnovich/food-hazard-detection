# %%
import pandas as pd

# %% [markdown]
# # Retrieval evaluation

# %%
df = pd.read_csv("../data/incidents_train.csv", index_col=False, dtype=str)
df = df.rename(columns={"Unnamed: 0": "id", "hazard-category": "hazard_category", "product-category": "product_category"})
documents = df.to_dict(orient="records")

# %%
from openai import OpenAI

client = OpenAI(
    base_url='http://localhost:11434/v1/',
    api_key='ollama',
)

# %%
documents[0]
# Out:
# {'id': '0',
#  'year': '1994',
#  'month': '1',
#  'day': '7',
#  'country': 'us',
#  'title': 'Recall Notification: FSIS-024-94',
#  'text': "Case Number: 024-94   \n            Date Opened: 07/01/1994   \n            Date Closed: 09/22/1994 \n    \n            Recall Class:  1   \n            Press Release (Y/N):  Y  \n    \n            Domestic Est. Number:  05893  P   \n              Name:  GERHARD'S NAPA VALLEY SAUSAGE\n    \n            Imported Product (Y/N):  N       \n            Foreign Estab. Number:  N/A\n    \n            City:  NAPA    \n            State:  CA   \n            Country:  USA\n    \n            Product:  SMOKED CHICKEN SAUSAGE\n    \n            Problem:  BACTERIA   \n            Description: LISTERIA\n    \n            Total Pounds Recalled:  2,894   \n            Pounds Recovered:  2,894",
#  'hazard_category': 'biological',
#  'product_category': 'meat, egg and dairy products',
#  'hazard': 'listeria monocytogenes',
#  'product': 'smoked sausage'}

# %%
prompt_template = """
You emulate a user of a food hazard detection application.
Formulate 5 questions this user might ask based on a food-incident record. 
Make the questions specific to this record.

The record:

'title': {title}
'hazard_category': {hazard_category}
'product_category': {product_category}
'hazard': {hazard}
'product': {product}

Provide the output in parsable JSON based on the following schema:

{{"questions": ["question1", "question2", ..., "question5"]}}
""".strip()

# %%
def generate_questions(doc):
    prompt = prompt_template.format(**doc)
    response = client.chat.completions.create(
        model='llama3.1',
        messages=[{"role": "user", "content": prompt}],
        temperature=0.2
    )

    return response.choices[0].message.content

# %%
from tqdm.auto import tqdm

# %%
import json

# %%
results = {}

# %%
for doc in tqdm(documents[300:400]): 
    doc_id = doc['id']
    if doc_id in results:
        continue

    questions_raw = generate_questions(doc)
    questions = json.loads(questions_raw.split("```")[1].lstrip("json"))['questions']
    q_from_dict = []
    for q in questions:
        if isinstance(q, dict):
            if q['text']:
                q_from_dict.append(q['text'])

    with open("../data/generated_questions_300.tsv", "a+") as myfile:
        if len(q_from_dict)>0:
            myfile.write("\t".join([doc_id, "\t".join(q_from_dict)]))
        else:
            myfile.write("\t".join([doc_id, "\t".join(questions)]))
        myfile.write("\n")
    results[doc_id] = questions_raw
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
df_final = pd.read_csv("../data/generated_questions_300.tsv", delimiter="\t", names=["id","q1","q2","q3","q4","q5"], header=None)

# %%
df_final.head()
# Out:
#     id                                                 q1  \
# 0  300  What type of other hazard was associated with ...
# 1  301  What is the nature of the alleged labelling/mi...
# 2  302  What was the nature of the labelling/misdescri...
# 3  303  What is the specific allergen present in Gold ...
# 4  304  What is the current status of the recall for P...
#
#                                                   q2  \
# 0  Was the recall related to a contamination issu...
# 1  Can you provide more information about the pro...
# 2  Was the potato salad recalled due to this inci...
# 3  Are there any other products from Gold Medal S...
# 4  Are there any similar products from other manu...
#
#                                                   q3  \
# 0  Can you provide more information about the fir...
# 1  How does Woolworths Limited's quality control ...
# 2  Can you provide more information about the No ...
# 3  How does the presence of cereals containing gl...
# 4  Has the Australian government issued any guide...
#
#                                                   q4  \
# 0  Did the recall affect any specific cuts or typ...
# 1  What are the potential health risks associated...
# 2  How did the company respond to the incident, a...
# 3  Are there any similar seafood products on the ...
# 4  Can I get a list of all the countries where Pr...
#
#                                                   q5
# 0  Are there any updates or follow-up actions tak...
# 1  Are there any similar incidents of labelling/m...
# 2  Are there any similar incidents involving Fran...
# 3  What steps can consumers take to avoid consumi...
# 4  Are there any updates on the investigation int...

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      100 non-null    int64
#  1   q1      100 non-null    object
#  2   q2      100 non-null    object
#  3   q3      100 non-null    object
#  4   q4      100 non-null    object
#  5   q5      100 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 4.8+ KB

# %%
results = df_final.to_dict(orient='records')

# %%
results
# Out:
# [{'id': 300,
#   'q1': 'What type of other hazard was associated with the recalled Angus beef product?',
#   'q2': 'Was the recall related to a contamination issue or a non-food safety concern?',
#   'q3': 'Can you provide more information about the firm that issued the recall on June 15, 2007?',
#   'q4': 'Did the recall affect any specific cuts or types of Angus beef products?',
#   'q5': 'Are there any updates or follow-up actions taken by regulatory agencies regarding this recall?'},
#  {'id': 301,
#   'q1': 'What is the nature of the alleged labelling/misdescription fraud involving Home Brand Scorched Almonds Milk Chocolate?',
#   'q2': "Can you provide more information about the product category 'cocoa and cocoa preparations, coffee and tea' and how it relates to this incident?",
#   'q3': "How does Woolworths Limited's quality control process fail to detect such mislabelling incidents?",
#   'q4': 'What are the potential health risks associated with consuming milk chocolates that have been mislabelled or misrepresented?',
#   'q5': 'Are there any similar incidents of labelling/misdescription fraud reported in the past involving Woolworths Limited or its Home Brand products?'},
#  {'id': 302,
#   'q1': "What was the nature of the labelling/misdescription issue with Franklins Pty Ltd's Potato Salad in Mayonnaise?",
#   'q2': 'Was the potato salad recalled due to this incident, and if so, what were the affected batch numbers?',
#   'q3': 'Can you provide more information about the No Frills store where the mislabelled product was sold?',
#   'q4': 'How did the company respond to the incident, and have they taken any corrective actions?',
#   'q5': 'Are there any similar incidents involving Franklins Pty Ltd or their products that I should be aware of?'},
#  {'id': 303,
#   'q1': "What is the specific allergen present in Gold Medal Snacks' Prawn Crackers?",
#   'q2': 'Are there any other products from Gold Medal Snacks that contain gluten, aside from this prawn snack?',
#   'q3': 'How does the presence of cereals containing gluten affect individuals with coeliac disease or gluten intolerance?',
#   'q4': 'Are there any similar seafood products on the market that also contain gluten?',
#   'q5': "What steps can consumers take to avoid consuming Gold Medal Snacks' Prawn Crackers if they have a gluten allergy or intolerance?"},
#  {'id': 304,
#   'q1': 'What is the current status of the recall for Primo Smallgoods—Corned Silverside?',
#   'q2': 'Are there any similar products from other manufacturers that have been contaminated with Listeria monocytogenes?',
#   'q3': 'Has the Australian government issued any guidelines or recommendations to consumers regarding the safe handling and consumption of precooked cooked beef meat products?',
#   'q4': 'Can I get a list of all the countries where Primo Smallgoods—Corned Silverside has been distributed, in case there have been similar incidents reported elsewhere?',
#   'q5': 'Are there any updates on the investigation into how Listeria monocytogenes contamination occurred at the Primo Smallgoods facility?'},
#  {'id': 305,
#   'q1': 'What was the specific reason for the mislabeling of Prestige Chocolate Ice Cream?',
#   'q2': 'Was there a recall issued for the affected ice cream products?',
#   'q3': 'How many people were potentially exposed to almonds through this incident?',
#   'q4': 'Were any other food products from Winn-Dixie Stores, Inc. involved in this incident?',
#   'q5': 'What steps did Winn-Dixie Stores, Inc. take to prevent similar incidents in the future?'},
#  {'id': 306,
#   'q1': 'What is the total number of units recalled by WI firm?',
#   'q2': 'Are there any reported cases of illness associated with this recall?',
#   'q3': 'How does the presence of E. coli in frozen beef patties pose a risk to consumers?',
#   'q4': 'Can you provide more information about the production dates and lot numbers affected by this recall?',
#   'q5': 'Has WI firm implemented any corrective actions or changes to their manufacturing process since this incident?'},
#  {'id': 307,
#   'q1': 'What is the exact nature of the plastic fragment found in the Bega So Extra Light grated cheese?',
#   'q2': 'Is there a risk assessment available for consumers who have consumed the affected product?',
#   'q3': 'How was the foreign body (plastic fragment) introduced into the product during manufacturing?',
#   'q4': 'Are there any similar incidents reported with this or other products from the same manufacturer?',
#   'q5': 'What corrective actions has the manufacturer taken to prevent such incidents in the future?'},
#  {'id': 308,
#   'q1': 'What was the reason for the recall of frozen pot pie products by MO Firm on Oct 11, 2007?',
#   'q2': 'Were any cases of salmonella reported as a result of consuming these recalled products?',
#   'q3': 'Can you provide more information about the product category (cereals and bakery products) being associated with a biological hazard like salmonella?',
#   'q4': 'Did the recall affect only frozen pot pie products or were other types of frozen pies also involved?',
#   'q5': 'What steps did MO Firm take to prevent similar incidents in the future after this recall?'},
#  {'id': 309,
#   'q1': 'What was the size and shape of the metal fragment found in the yoghurt?',
#   'q2': 'Was the yoghurt recalled from stores due to this incident?',
#   'q3': 'Can you provide more information about the manufacturing process for Baby Yoplait and Yoplait Elivaé yoghurts?',
#   'q4': 'Were any other types of foreign bodies (besides metal fragments) reported in these products during the same production period?',
#   'q5': 'Is there a risk assessment or root cause analysis available for this incident that I can access?'},
#  {'id': 310,
#   'q1': 'What is the name of the company that issued the recall (Welsh Country Foods Ltd)?',
#   'q2': 'Are there any specific batch numbers or dates associated with the recalled lamb meat and offal?',
#   'q3': 'How might consumers be exposed to veterinary medicine residues in veal meat and offals from Welsh Country Foods Ltd?',
#   'q4': 'Has the UK Food Standards Agency (or equivalent) taken any action against Welsh Country Foods Ltd for this incident?',
#   'q5': 'Are there any similar recalls or incidents involving Welsh Country Foods Ltd that I should be aware of?'},
#  {'id': 311,
#   'q1': 'What type of foreign bodies were found in the Coles Group Ltd branded thin BBQ Sausages?',
#   'q2': 'Are there any other products from Coles Group Ltd that have been recalled due to foreign body contamination?',
#   'q3': 'Can I get a list of all the brands and product names mentioned in this incident record?',
#   'q4': 'How many incidents of foreign bodies in meat, egg and dairy products have been reported in the past year?',
#   'q5': 'Are there any specific guidelines or recommendations for handling and cooking BBQ sausages to minimize the risk of foreign body contamination?'},
#  {'id': 312,
#   'q1': 'What is the current status of the Coles Group Ltd recall for the Basil Pesto Dip product?',
#   'q2': 'Has there been any update on the root cause analysis for the Listeria monocytogenes contamination in the basil pesto sauce?',
#   'q3': 'Can you provide a list of all products that have been recalled by Coles Group Ltd due to biological hazards since 2020?',
#   'q4': 'What are the typical shelf life and storage conditions for the Basil Pesto Dip product to prevent Listeria monocytogenes growth?',
#   'q5': 'Are there any similar incidents of Listeria monocytogenes contamination in other basil pesto sauce products reported by regulatory agencies?'},
#  {'id': 313,
#   'q1': 'What is the nature of the hazard found in the Woolworths Home brand white sliced sandwich bread?',
#   'q2': 'Is there a risk assessment available for glass fragments in cereals and bakery products like bread?',
#   'q3': 'Has this incident led to any product recalls or withdrawals from the market?',
#   'q4': 'Can I see the specific batch numbers or production dates associated with this contaminated bread product?',
#   'q5': "Are there any similar incidents of foreign bodies in Woolworths' Home brand products that have been reported?"},
#  {'id': 314,
#   'q1': 'What is the size of the glass fragment found in the bread?',
#   'q2': 'Was the bread produced at The Good Stuff Bakery or was it sourced from another supplier?',
#   'q3': "Has there been any previous incidents of foreign bodies in The Good Stuff Bakery's products?",
#   'q4': 'Can I see a photo of the glass fragment that was found in the bread?',
#   'q5': 'What is the current status of the recall process for this product?'},
#  {'id': 315,
#   'q1': 'What is the exact nature of the metal contamination found in Marks & Spencer cheesecake desserts?',
#   'q2': 'Are there any reported cases of consumers consuming these contaminated cheesecakes and experiencing adverse health effects?',
#   'q3': 'Can I get a list of all products recalled by Marks & Spencer due to food safety concerns within the last year?',
#   'q4': 'How does Marks & Spencer plan to prevent similar incidents in the future, especially with regards to metal contamination in their baked goods?',
#   'q5': 'Are there any regulatory actions being taken against Marks & Spencer for this incident, and if so, what are they?'},
#  {'id': 316,
#   'q1': 'What is the specific date range for which these ground beef products were produced?',
#   'q2': 'Are there any specific lots or batch numbers associated with this recall?',
#   'q3': 'Can you provide more information about the potential risk of E. coli O157:H7 contamination in ground beef products?',
#   'q4': 'How can consumers identify whether they have purchased one of the recalled ground beef products?',
#   'q5': 'What are the recommended steps for consumers to take if they have already consumed a recalled product?'},
#  {'id': 317,
#   'q1': 'What is the current status of the recall for Curlwaa Orange Juice—Various Products?',
#   'q2': 'Are there any reported cases of salmonella illness associated with consuming these juices?',
#   'q3': "Which specific products within the 'Curlwaa Orange Juice—Various Products' category have been contaminated with salmonella?",
#   'q4': 'Has the manufacturer taken corrective action to prevent future contamination incidents?',
#   'q5': 'What is the recommended course of action for consumers who may have purchased or consumed these potentially contaminated juices?'},
#  {'id': 318,
#   'q1': 'What is the size and shape of the metal fragment found in the Woolworths bread soft wholemeal loaf?',
#   'q2': 'Is there a risk assessment available for this incident to determine if it was an isolated occurrence or a systemic issue?',
#   'q3': 'Has Woolworths recalled any other batches of their bread products due to similar foreign body contamination incidents?',
#   'q4': 'What is the typical manufacturing process for Woolworths bread, and where might metal fragments be introduced during production?',
#   'q5': 'Are there any regulatory actions being taken against Woolworths as a result of this incident?'},
#  {'id': 319,
#   'q1': "What is the nature of the foreign body found in Mrs Mac's products?",
#   'q2': "Are all individually wrapped Mrs Mac's Good Eating products affected by this recall?",
#   'q3': 'Can you confirm that only plastic fragments were found in the Red Embers Chicken Leek & Mushroom Pies?',
#   'q4': "How does this incident relate to previous recalls involving Mrs Mac's or Bakewell products?",
#   'q5': 'What steps should consumers take if they have purchased any of the recalled products?'},
#  {'id': 320,
#   'q1': 'What was the chemical hazard found in the Parmalat Australia Limited PhysiCAL No Fat Milk product?',
#   'q2': 'Is it safe for consumers to consume milk products from the same production line as the affected batch?',
#   'q3': 'Were any other dairy products contaminated with the same chemical hazard?',
#   'q4': 'Did the manufacturer recall or re-label the affected product, and if so, what was the outcome?',
#   'q5': "Can I get more information about the 'other not classified chemical hazards' mentioned in this incident?"},
#  {'id': 321,
#   'q1': 'What type of toxin was detected in the tuna steaks?',
#   'q2': 'Are there any similar incidents involving tuna products from Indonesia that I should be aware of?',
#   'q3': 'Has Foodland issued a recall for these specific tuna steaks sold in South Australia?',
#   'q4': 'Can you provide more information about the Daruma Tuna Steaks product, such as its packaging and labeling?',
#   'q5': 'What are the potential health risks associated with consuming tuna steaks contaminated with this toxin?'},
#  {'id': 322,
#   'q1': 'What is the nature of the labelling/misdescription hazard found in Healtheries Kidscare Rice Rounds—Cheese and Bacon Flavour?',
#   'q2': 'How does this incident relate to other similar products or brands under Health Brands Australia?',
#   'q3': 'Can you provide more information about the regulatory actions taken against Health Brands Australia following this incident?',
#   'q4': 'What steps can consumers take to identify potentially mislabelled food products like Healtheries Kidscare Rice Rounds—Cheese and Bacon Flavour?',
#   'q5': 'Are there any updates on whether Healtheries Kidscare Rice Rounds—Cheese and Bacon Flavour is still available for purchase, or has it been recalled?'},
#  {'id': 323,
#   'q1': "What is the specific product within Pierre's Ice Cream Company's Homestyle brand that contains undeclared peanut butter cup candies?",
#   'q2': 'Is it confirmed that the peanut butter cup candies are a separate ingredient from the Dutch chocolate ice cream itself?',
#   'q3': "Were any other products from Pierre's Ice Cream Company affected by this allergy alert, or was it isolated to just the Homestyle Dutch chocolate ice cream?",
#   'q4': "What is the recommended course of action for consumers who have already consumed Pierre's Ice Cream Company's Homestyle Dutch chocolate ice cream and are concerned about potential peanut exposure?",
#   'q5': "Has Pierre's Ice Cream Company taken any steps to prevent similar incidents in the future, such as updating their labeling or manufacturing processes?"},
#  {'id': 324,
#   'q1': 'What is the nature of the allergen hazard found in Woolworths Limited—Home Brand Oyster Sauce?',
#   'q2': "Is there any information about the product's packaging or labeling that could have contributed to the hazard?",
#   'q3': 'Can you provide more details about the specific cereals containing gluten that were identified as a hazard in this product?',
#   'q4': 'How does this incident relate to other food products in the soups, broths, sauces and condiments category?',
#   'q5': 'Are there any recommendations or guidelines provided for consumers who may have ingested Woolworths Limited—Home Brand Oyster Sauce?'},
#  {'id': 325,
#   'q1': "What is the current status of the recall for P & M Quality Smallgoods Pty Ltd's Courtway Continental Double Smoked Leg Ham, Deli Style Slices?",
#   'q2': 'Has there been any reported illness or death associated with consuming this product due to Listeria monocytogenes contamination?',
#   'q3': 'Are there any similar products from other manufacturers that have also been contaminated with Listeria monocytogenes?',
#   'q4': 'What are the recommended safe handling and storage procedures for ham products like Courtway Continental Double Smoked Leg Ham, Deli Style Slices?',
#   'q5': 'Is it possible to get a breakdown of the number of people affected by this food incident in terms of age groups or geographic locations?'},
#  {'id': 326,
#   'q1': 'What is the current status of the recall for Farmwood Delicatessen Smoked Chicken Breast?',
#   'q2': 'Has there been any update on the investigation into the Listeria monocytogenes contamination in the chicken breast product?',
#   'q3': 'Are there any similar food safety incidents involving smoked meats or dairy products that I should be aware of?',
#   'q4': 'Can you provide more information about the Farmwood Delicatessen facility where the contaminated chicken breast was produced?',
#   'q5': 'What are the recommended steps for consumers who may have purchased and consumed the affected Smoked Chicken Breast product?'},
#  {'id': 327,
#   'q1': 'What is the current status of the Alba Cheese—Shredded Mozzarella product recall?',
#   'q2': 'Has there been any update on the root cause analysis for this Listeria monocytogenes contamination incident?',
#   'q3': 'Are there any similar incidents involving mozzarella cheese products in other countries or regions?',
#   'q4': 'Can I view a list of all dairy products that have been contaminated with Listeria monocytogenes in the past 5 years?',
#   'q5': 'What are the recommended steps for consumers to take if they suspect they may have purchased and consumed this contaminated product?'},
#  {'id': 328,
#   'q1': 'What is the nature of the pathogenic bacteria detected in the Safcol tuna products?',
#   'q2': 'Are there any similar incidents reported for seafood products with gold foil top packaging?',
#   'q3': 'Can you provide more information about the Gold Foil Top Packaging used by Safcol and its potential impact on food safety?',
#   'q4': 'How does this incident affect the overall risk assessment for tuna products in our inventory?',
#   'q5': 'Have there been any recalls or regulatory actions taken against Safcol as a result of this incident?'},
#  {'id': 329,
#   'q1': "What was the quantity of Rogan Josh Simmer Sauce produced by Patak's Foods Limited that contained a glass fragment?",
#   'q2': 'Was the glass fragment found in a specific batch or lot number of the product?',
#   'q3': 'How did the glass fragment get into the cooking sauce during production?',
#   'q4': 'Has there been any recall issued for this product due to the presence of a foreign body?',
#   'q5': "What is the current status of the investigation into the contamination of Patak's Foods Limited—Rogan Josh Simmer Sauce?"},
#  {'id': 330,
#   'q1': 'What is the specified risk material (SRM) that was found in the recalled beef products?',
#   'q2': 'Is it true that only cow heads were recalled, or were other beef products also affected?',
#   'q3': 'Can you provide more information about the firm that issued the recall on April 4, 2008?',
#   'q4': 'How does this recall relate to food safety regulations regarding SRM in meat and dairy products?',
#   'q5': 'Are there any updates on whether the recalled beef products have been safely disposed of or re-labeled?'},
#  {'id': 331,
#   'q1': 'What were the specific Kroger stores affected by this recall?',
#   'q2': 'Are eggs and egg products a common allergen hazard in ice cream products?',
#   'q3': 'Can you provide more information about the private selection brand of ice cream that was recalled?',
#   'q4': 'How did the manufacturer become aware of the potential hazard in their product?',
#   'q5': 'Were there any reported cases of allergic reactions or illnesses related to this recall?'},
#  {'id': 332,
#   'q1': 'What is the nature of the metal fragment found in the Home Brand Mini Spring Rolls?',
#   'q2': 'Are there any similar incidents reported for Woolworths Limited products within the last year?',
#   'q3': 'How many packs of the affected product were recalled by the manufacturer?',
#   'q4': 'Can I get a list of all products that have been recalled due to foreign bodies in the past 6 months?',
#   'q5': 'What is the current status of the investigation into this incident, and are there any updates on when the results will be released?'},
#  {'id': 333,
#   'q1': 'What is the nature of the metal fragment found in the Darshan Savoury Rolls?',
#   'q2': 'Was the incident related to a specific batch or production run of the product?',
#   'q3': 'Has there been any recall or withdrawal of the affected product from the market?',
#   'q4': 'Are there any similar incidents reported involving Australian International Foods Pty Ltd or their products?',
#   'q5': 'What is the recommended course of action for consumers who may have purchased and consumed the affected product?'},
#  {'id': 334,
#   'q1': 'What is the nature of the glass fragment found in the Woolworths Limited BBQ Chickens Extra Large product?',
#   'q2': 'Was the glass fragment visible or was it embedded within the product?',
#   'q3': 'Has there been any recall issued by Woolworths Limited for this specific product batch?',
#   'q4': 'Are customers who have purchased and consumed this product at risk of injury from the glass fragment?',
#   'q5': 'What steps can I take as a consumer to identify potential hazards in other ready-to-eat products?'},
#  {'id': 335,
#   'q1': "What is the nature of the chemical hazard found in Woolworths Limited's lamb products?",
#   'q2': 'Are there any similar incidents involving lamb or other meat products that have been reported recently?',
#   'q3': 'Has Woolworths Limited issued any recalls or statements regarding this incident, and if so, what were they?',
#   'q4': 'Can I see a list of specific lamb products from Woolworths Limited that are affected by this chemical hazard?',
#   'q5': 'What steps can consumers take to minimize their risk of exposure to this chemical hazard in lamb products?'},
#  {'id': 336,
#   'q1': "What is the nature of the 'other not classified chemical hazards' found in the Supa IGA Large BBQ Chickens?",
#   'q2': 'Is it possible that consumers who ate the affected product may have ingested this chemical hazard without knowing it?',
#   'q3': 'Can you provide more information about the prepared dishes and snacks category, specifically regarding chemical hazards like this one?',
#   'q4': "What steps can be taken to prevent similar incidents involving 'other not classified chemical hazards' in ready-to-eat cook meals?",
#   'q5': 'Are there any regulatory guidelines or standards that Supa IGA should follow to ensure their products are safe from such chemical hazards?'},
#  {'id': 337,
#   'q1': "What is the nature of the labelling/misdescription hazard found at Tony's Meats?",
#   'q2': 'How does the mislabelling of the Greek BBQ Butterfly Lamb Leg product affect consumer safety?',
#   'q3': 'Can you provide more information about the specific ingredients or allergens that were incorrectly labelled on the affected products?',
#   'q4': "Were any other products from Tony's Meats recalled or affected by this incident, aside from the Pork Loin Cherry and Walnut, Pork Loin Apricot and Macadamia & Greek BBQ Butterfly Lamb Leg?",
#   'q5': "What actions has the relevant regulatory authority taken in response to this labelling/misdescription hazard at Tony's Meats?"},
#  {'id': 338,
#   'q1': 'What is specified risk material (SRM) and how does it relate to beef products?',
#   'q2': 'Is SRM a type of allergen or a chemical contaminant?',
#   'q3': 'Can you provide more information about the recall notice issued by the Texas Firm on June 26, 2008?',
#   'q4': 'How can I verify if the recalled cattle heads were distributed to my area or region?',
#   'q5': 'What are the potential health risks associated with consuming beef products contaminated with SRM?'},
#  {'id': 339,
#   'q1': "What is the specific product within the 'Home Brand—Sultanas Milk Chocolate' that contains peanuts?",
#   'q2': 'Is there a risk of cross-contamination with peanuts in other products from this manufacturer?',
#   'q3': 'How does the presence of peanuts in milk chocolates affect consumers with peanut allergies?',
#   'q4': 'Are there any regulatory requirements or guidelines for labeling products containing peanuts?',
#   'q5': 'What steps can I take to prevent exposure to peanuts in milk chocolate products?'},
#  {'id': 340,
#   'q1': 'What is BT63 genetically modified rice and how does it differ from non-GM rice?',
#   'q2': 'Can you provide more information about the recall process initiated by Day In Import & Export Co Ltd?',
#   'q3': 'How might the presence of unauthorised GM rice in Guilin Rice Flour Noodles affect consumer health?',
#   'q4': 'Are there any similar incidents involving genetically modified ingredients in food products?',
#   'q5': 'What steps can consumers take to identify and avoid consuming products containing unauthorised GM ingredients?'},
#  {'id': 341,
#   'q1': 'What is the specific type of gluten-containing cereal that was found in the Whisk and Pin—Gluten Free Muesli product?',
#   'q2': 'Is it possible for consumers with celiac disease or non-celiac gluten sensitivity to consume this muesli without experiencing adverse reactions?',
#   'q3': 'Can you provide more information about the manufacturing process of the Whisk and Pin—Gluten Free Muesli, as it may be relevant to understanding how gluten contamination occurred?',
#   'q4': "How does the presence of gluten in a product labeled 'gluten-free' affect consumer trust in food manufacturers and regulatory agencies?",
#   'q5': 'Are there any similar incidents or recalls involving gluten-containing cereals or mueslis that have been reported in recent years?'},
#  {'id': 342,
#   'q1': 'What is the specific risk material (SRM) found in the recalled beef products?',
#   'q2': 'Is there any information available about the cattle heads that were part of the recall?',
#   'q3': 'How many pounds or units of beef products were affected by this recall?',
#   'q4': 'Are there any similar recalls related to SRM in beef products from Texas firms around the same time period?',
#   'q5': 'What are the potential health risks associated with consuming beef contaminated with SRM?'},
#  {'id': 343,
#   'q1': 'What is the specific reason for the withdrawal of cooked bacon used in three own-brand chicken and bacon sandwich fillers?',
#   'q2': 'Is there a risk assessment available for the thermal processed pork meat that was contaminated with salmonella?',
#   'q3': 'Can you provide more information about the possible contamination route for the cooked bacon used in these sandwich fillers?',
#   'q4': 'Are there any similar incidents of salmonella contamination reported in the past involving Dawn Farm Foods Ltd or their products?',
#   'q5': 'What is the current status of the investigation into this incident and are there any updates on product recalls?'},
#  {'id': 344,
#   'q1': 'What is the nature of the allergen hazard found in Weight Watchers Australia—Rich Toffee Bars?',
#   'q2': 'Are eggs and egg products a common ingredient in confectionery products like toffee?',
#   'q3': 'Can you provide more information about the specific product, Rich Toffee Bars, that was affected by this incident?',
#   'q4': 'How does the presence of eggs and egg products in Weight Watchers Australia—Rich Toffee Bars impact consumers with egg allergies?',
#   'q5': 'Are there any similar incidents or recalls related to confectionery products containing eggs and egg products?'},
#  {'id': 345,
#   'q1': 'What is the nature of the allergenic hazard in these yoghurt sultanas tubs?',
#   'q2': 'Are peanuts and peanut products commonly used as ingredients in yoghurt products like this one?',
#   'q3': 'How might consumers be exposed to peanuts through this product, given its packaging and storage practices?',
#   'q4': 'Have there been any previous incidents or recalls related to allergens in similar yoghurt products?',
#   'q5': 'What steps can I take as a consumer to minimize my risk of exposure to peanuts when purchasing yoghurt sultanas tubs?'},
#  {'id': 346,
#   'q1': 'What is the estimated quantity of minced beef affected by this incident?',
#   'q2': 'Was the plastic fragment found in a single product or multiple products from the same batch?',
#   'q3': 'Has Woolworths recalled any other meat products that may have been contaminated with foreign bodies?',
#   'q4': 'Can you provide more information about the type and size of the plastic fragment found in the minced beef?',
#   'q5': 'What is the current status of the investigation into this incident, and are there any updates on corrective actions taken by Woolworths?'},
#  {'id': 347,
#   'q1': 'What is the nature of the metal fragment found in the McCain Stir Fry Vegetables Pasta Alfredo?',
#   'q2': 'Was the product recalled due to this incident?',
#   'q3': 'Can you provide more information about the foreign body hazard category and how it relates to this specific product?',
#   'q4': 'Is there a risk assessment available for consumers who may have consumed this product?',
#   'q5': 'What steps can I take as a consumer to identify potential metal fragments in similar products?'},
#  {'id': 348,
#   'q1': 'What is the nature of the chemical hazard reported for Kaisi Australia Pty Ltd—Kirin Milk Tea?',
#   'q2': 'Is there any information available about the potential health risks associated with consuming tea contaminated with this chemical?',
#   'q3': 'Can you provide details on the product category (cocoa and cocoa preparations, coffee and tea) and how it relates to the hazard?',
#   'q4': 'What steps has Kaisi Australia Pty Ltd taken or is taking in response to this incident?',
#   'q5': 'Are there any similar incidents of chemical hazards reported for other products within the same product category?'},
#  {'id': 349,
#   'q1': 'What is the nature of the undeclared milk protein in the Kroger Value Semi Sweet Chocolate Chips?',
#   'q2': 'Was the recall initiated by Barry Callebaut USA LLC or was it mandated by regulatory authorities?',
#   'q3': "Can you provide more information about the product category 'cocoa and cocoa preparations, coffee and tea'?",
#   'q4': 'How does this incident relate to other food safety issues involving milk allergens in chocolate products?',
#   'q5': 'Are there any updates on the status of the recall or subsequent actions taken by Barry Callebaut USA LLC?'},
#  {'id': 350,
#   'q1': 'What is the current status of the recall for Bella Fantasia Hazelnut Gelato and Bacio Romantico Gelato?',
#   'q2': 'Are there any reported cases of illness associated with consuming this product?',
#   'q3': 'Can you provide more information about the Listeria monocytogenes contamination found in the ice cream?',
#   'q4': 'Has the manufacturer taken steps to sanitize their production facilities and equipment?',
#   'q5': 'What is the recommended safe handling and storage procedure for consumers who may have purchased this product?'},
#  {'id': 351,
#   'q1': "What is the nature of the allergen hazard identified in Malouf's Spice Mezza?",
#   'q2': "Is it possible to identify which specific spice mix within Country Cuisine Pty Ltd's product range contains nuts?",
#   'q3': 'Can you provide more information about the regulatory requirements for labelling allergens in herbs and spices products?',
#   'q4': "How does this incident affect the overall risk assessment of Country Cuisine Pty Ltd's product portfolio?",
#   'q5': 'Are there any similar incidents involving nut allergens in spice mixes reported by other companies?'},
#  {'id': 352,
#   'q1': 'What is the estimated volume of Angostura Lemon Lime and Bitters & Angostura Lemon Lime and Bitters light products that may have been contaminated with glass fragments?',
#   'q2': 'Has there been any recall or product withdrawal initiated by the manufacturer, Island2island Beverage Comp. Pty Ltd, due to this incident?',
#   'q3': 'Can you provide more information about the type of glass fragment found in the product? Was it a sharp or blunt edge?',
#   'q4': 'Are there any similar incidents involving glass fragments in other products from Island2island Beverage Comp. Pty Ltd that I should be aware of?',
#   'q5': 'What are the recommended steps for consumers who may have purchased and consumed Angostura Lemon Lime and Bitters & Angostura Lemon Lime and Bitters light products during this time period?'},
#  {'id': 353,
#   'q1': 'What type of foreign body was found in the Cadbury Boost Totally Nuts bar?',
#   'q2': 'Is it possible that the plastic fragment was introduced during the packaging process?',
#   'q3': 'Has there been a recall issued for this specific product or brand due to similar incidents?',
#   'q4': 'Can you provide more information about the size and shape of the plastic fragment found in the product?',
#   'q5': 'Are there any guidelines or regulations in place to prevent such foreign bodies from entering food products?'},
#  {'id': 354,
#   'q1': 'What is the specific type of dioxins that were found in the fresh pork products?',
#   'q2': 'Are there any other meat, egg and dairy products from this firm that have been recalled due to chemical hazards?',
#   'q3': 'How does the presence of dioxins affect the safety of consuming fresh pork products?',
#   'q4': 'Has the FDA or USDA taken any action against this NY firm for the recall of their fresh pork products?',
#   'q5': 'What steps can consumers take to minimize exposure to dioxins in their diet?'},
#  {'id': 355,
#   'q1': 'What is the specific type of fresh pork products recalled by FL Firm?',
#   'q2': 'How does the presence of dioxins affect human health?',
#   'q3': 'Are there any similar recalls involving meat, egg and dairy products in the past?',
#   'q4': 'Can you provide more information about the recall process initiated by FL Firm?',
#   'q5': 'Is it possible to get a list of all fresh pork products recalled due to dioxin contamination?'},
#  {'id': 356,
#   'q1': 'What is the current status of the recall for fresh pork products contaminated with dioxins?',
#   'q2': 'Are there any similar recalls involving meat, egg and dairy products that I should be aware of?',
#   'q3': 'Can you provide more information about the source of the dioxin contamination in the recalled fresh pork products?',
#   'q4': 'How can consumers identify whether they have purchased or consumed the recalled fresh pork products?',
#   'q5': 'Is there a risk assessment available for this incident that I can access?'},
#  {'id': 357,
#   'q1': 'What is the nature of the foreign matter suspected in the bottled mineral water?',
#   'q2': 'Has there been any recall issued for this specific product or batch?',
#   'q3': 'Are there any similar incidents reported with other products from the same manufacturer?',
#   'q4': 'How does this incident affect the overall safety rating of non-alcoholic beverages in our database?',
#   'q5': 'Can we get a list of all food-incident records related to foreign bodies in bottled drinks?'},
#  {'id': 358,
#   'q1': 'What is the estimated quantity of lamb products affected by this incident?',
#   'q2': 'Has Woolworths Limited issued a public recall notice for these products yet?',
#   'q3': 'Can you provide more information about the type of plastic fragment found in the lamb product?',
#   'q4': 'Are there any similar incidents involving foreign bodies in meat, egg and dairy products reported recently?',
#   'q5': 'What is the status of the investigation into this incident?'},
#  {'id': 359,
#   'q1': 'What was the specific product affected by the recall?',
#   'q2': 'Was this incident related to a manufacturing facility or a distribution issue?',
#   'q3': 'Can you provide more information about the Salmonella strain involved in this outbreak?',
#   'q4': 'Were there any reported cases of illness or death associated with this incident?',
#   'q5': 'Is it possible to view a list of all products recalled by the Peanut Corporation of America in 2009?'},
#  {'id': 360,
#   'q1': "What was the specific reason for the recall of Kroger's ice cream products?",
#   'q2': 'Are there any other types of frozen desserts that were recalled due to salmonella contamination?',
#   'q3': 'How many people were affected by consuming the contaminated ice cream products?',
#   'q4': 'Were the ice cream products distributed in a specific geographic region or nationwide?',
#   'q5': 'What steps can consumers take to avoid similar food hazards in the future?'},
#  {'id': 361,
#   'q1': 'What is the nature of the biological hazard involved in this recall (salmonella)?',
#   'q2': 'Is there a risk of contamination for other ice cream products from the same manufacturer?',
#   'q3': 'How does this recall affect consumers who have already consumed the recalled ice cream product?',
#   'q4': 'Are there any specific symptoms or health effects associated with salmonella poisoning that I should be aware of?',
#   'q5': 'What are the next steps for consumers to take if they suspect their ice cream has been contaminated?'},
#  {'id': 362,
#   'q1': 'What is the specific reason for the recall of Blue Stilton and Shropshire Blue Cheese products?',
#   'q2': 'Are there any reported cases of illness or death associated with consuming these cheese products?',
#   'q3': 'Can I still consume these cheese products if they are past their expiration date but have been stored properly?',
#   'q4': 'How can I identify which specific batches of Blue Stilton and Shropshire Blue Cheese are being recalled?',
#   'q5': 'What steps should consumers take to minimize the risk of Listeria monocytogenes contamination when handling cheese products?'},
#  {'id': 363,
#   'q1': 'What was the specific reason for the recall of peanut products by Peanut Corporation of America in 2009?',
#   'q2': 'Are there any other types of nuts or nut products that were affected by this salmonella outbreak?',
#   'q3': 'Can you provide more information about the scope of the recall, including which states were impacted?',
#   'q4': 'Were there any reported cases of illness or death related to this peanut product contamination?',
#   'q5': 'Is it still safe for consumers to purchase and consume peanuts from Peanut Corporation of America?'},
#  {'id': 364,
#   'q1': 'What is the nature of the possible health risk associated with these ice cream novelty products?',
#   'q2': 'Is salmonella a common hazard in ice cream products, or was this an isolated incident?',
#   'q3': 'Were any specific lots or batches of ice cream recalled as part of this voluntary recall?',
#   'q4': 'Can you provide more information about Fieldbrook Foods Corp. and their food safety practices?',
#   'q5': 'Are there any similar recalls or incidents involving salmonella contamination in ice cream products?'},
#  {'id': 365,
#   'q1': 'What is the specific product that was recalled by House of Flavors in 2009?',
#   'q2': 'Is it confirmed that the recall was due to Salmonella contamination?',
#   'q3': 'Were there any reported cases of illness related to consuming this ice cream?',
#   'q4': 'Can I still purchase ice cream from House of Flavors if they issued a voluntary recall in 2009?',
#   'q5': "What is the current status of the product category 'ices and desserts' regarding biological hazards like Salmonella?"},
#  {'id': 366,
#   'q1': 'What was the specific product affected by the salmonella contamination?',
#   'q2': 'Was there a recall issued for the contaminated ice cream products?',
#   'q3': 'How many people were reported to have gotten sick from consuming the contaminated ice cream?',
#   'q4': 'Were any other Velvet Ice Cream products besides the pulling cone ice cream implicated in this incident?',
#   'q5': 'What was the source of the salmonella contamination identified by investigators?'},
#  {'id': 367,
#   'q1': 'What is the specific ice cream product that was recalled due to salmonella contamination?',
#   'q2': 'Was the recall issued by HP Hood LLC for all types of ice cream products or only certain flavors?',
#   'q3': 'Can you provide more information about the biological hazard (salmonella) detected in the ice cream products?',
#   'q4': 'Were any other food products besides ice cream affected by this recall incident?',
#   'q5': 'What was the date range during which the recalled ice cream products were sold to consumers?'},
#  {'id': 368,
#   'q1': "What is the specific product name that was recalled by Perry's Ice Cream Company?",
#   'q2': 'Is it confirmed that the recall was initiated due to a salmonella contamination?',
#   'q3': 'Were any other types of ice cream products affected by this recall besides peanut butter ice cream?',
#   'q4': "Can I assume that all ice cream products from Perry's Ice Cream Company are safe for consumption now?",
#   'q5': 'What is the current status of the recall - has it been completed or is it still ongoing?'},
#  {'id': 369,
#   'q1': 'What is the specific ingredient in Heinz Dijon Mustard Sauce with Orange that contains eggs?',
#   'q2': 'Is it possible for consumers who are allergic to eggs to consume this product without experiencing an adverse reaction?',
#   'q3': 'How does the presence of egg products in a mustard sauce affect its shelf life and storage requirements?',
#   'q4': 'Can you provide information on any recalls or warnings issued by regulatory agencies regarding Heinz Dijon Mustard Sauce with Orange due to the egg hazard?',
#   'q5': 'Are there any similar food products within the soups, broths, sauces, and condiments category that also contain eggs as a hazard?'},
#  {'id': 370,
#   'q1': 'What was the specific reason for the recall of peanuts from Safeway stores with nut kiosks?',
#   'q2': 'Were any other types of nuts or products contaminated with Salmonella during this incident?',
#   'q3': 'How many stores were affected by the recall, and what was the geographic scope of the impacted area?',
#   'q4': 'Did the recall involve only peanut products sold directly at the nut kiosks, or also those purchased from the main store shelves?',
#   'q5': 'Were there any reported cases of foodborne illness associated with this Salmonella contamination?'},
#  {'id': 371,
#   'q1': "What is the specific product that was recalled by Pierre's Ice Cream Company?",
#   'q2': 'Is it true that the recall was initiated due to an expanded peanut recall by Peanut Corporation of America (PCA)?',
#   'q3': 'Can you confirm if Salmonella is indeed the hazard associated with this incident?',
#   'q4': 'Does this recall affect only sundae-cone style products or other types of ice cream as well?',
#   'q5': "Was Pierre's Ice Cream Company forced to issue a recall, or did they do so voluntarily?"},
#  {'id': 372,
#   'q1': 'What is the specific ice cream product that was recalled due to possible salmonella contamination?',
#   'q2': 'Is it confirmed that the recall was indeed voluntary or were there regulatory actions involved?',
#   'q3': 'How many cases of salmonella illness have been reported in relation to this incident?',
#   'q4': 'Were any other food products from Super Store Industries also affected by this recall?',
#   'q5': 'What are the recommended steps for consumers who may have purchased and consumed the recalled ice cream product?'},
#  {'id': 373,
#   'q1': 'What was the specific reason for recalling multiple brands of tin roof sundae ice cream?',
#   'q2': 'How many brands of ice cream were affected by this recall?',
#   'q3': 'Was the peanut corporation of america recall related to a contamination issue with peanuts or another ingredient?',
#   'q4': 'Are there any similar recalls involving ice cream products that I should be aware of?',
#   'q5': 'What steps can consumers take to minimize their risk of consuming contaminated ice cream?'},
#  {'id': 374,
#   'q1': 'What is the specific type of ice cream novelty that was recalled?',
#   'q2': 'Is there a confirmed case of salmonella illness linked to this recall?',
#   'q3': 'Can you provide more information about the possible health risk associated with this recall?',
#   'q4': 'Were any other food products or companies affected by this recall?',
#   'q5': 'Has the company, Ice Cream Specialties, taken steps to prevent similar recalls in the future?'},
#  {'id': 375,
#   'q1': 'What is the specific type of ice cream product that was recalled due to the expanded peanut recall?',
#   'q2': 'Is there a known link between peanuts and salmonella contamination in ice cream products?',
#   'q3': 'Were any other dairy or ice cream products from Umpqua Dairy affected by this recall?',
#   'q4': 'Can you provide more information on the Peanut Corporation of America (PCA) and their role in this recall?',
#   'q5': "Are there any recommendations for consumers who may have consumed Umpqua Dairy's Tin Roof Sundae Ice Cream product?"},
#  {'id': 376,
#   'q1': 'What is the specific type of ice cream that was recalled due to possible salmonella contamination?',
#   'q2': 'Is there any information available about the source of the salmonella contamination in the ice cream?',
#   'q3': 'Were any other products from House of Flavors affected by this recall?',
#   'q4': 'Can I get a list of states or countries where the recalled ice cream was distributed?',
#   'q5': 'Are there any updates on whether anyone has been reported to have gotten sick from consuming the contaminated ice cream?'},
#  {'id': 377,
#   'q1': 'What was the specific product affected by this recall (i.e. what type of ice cream)?',
#   'q2': 'Was the recall related to a contamination issue at the manufacturing facility or a supplier?',
#   'q3': 'Are there any similar recalls involving salmonella and ice cream products in the same time period?',
#   'q4': 'Did the recall involve other products besides Nutty Sundae Cones, such as other flavors of ice cream?',
#   'q5': 'What was the outcome of the investigation into the source of the salmonella contamination?'},
#  {'id': 378,
#   'q1': 'What is the nature of the biological hazard involved in this recall (salmonella)?',
#   'q2': 'Is ice cream a high-risk product for salmonella contamination?',
#   'q3': 'Can you provide more information about the Ice Cream Nut Roll product that was recalled?',
#   'q4': 'How does this incident relate to other food recalls involving ices and desserts?',
#   'q5': 'What are the potential health risks associated with consuming contaminated ice cream?'},
#  {'id': 379,
#   'q1': "What was the specific reason for the recall of Prairie Farms Dairy's ice cream products?",
#   'q2': 'Are there any reported cases of salmonella infections associated with consuming this product?',
#   'q3': 'Can you provide more information about the voluntary nationwide recall and how it was implemented?',
#   'q4': 'How long ago did the recall occur, and has the affected product been reintroduced to the market?',
#   'q5': 'What steps can consumers take to protect themselves from potential salmonella contamination when purchasing ice cream products?'},
#  {'id': 380,
#   'q1': 'What is the specific ice cream flavor that was recalled due to salmonella contamination?',
#   'q2': 'Is there any information available about the production dates or batch numbers of the affected ice cream products?',
#   'q3': "Were any other Braum's Ice Cream and Dairy Stores products besides premium ice cream flavors also recalled?",
#   'q4': 'How did the salmonella contamination occur in the ice cream products, according to the recall announcement?',
#   'q5': 'Are there any recommendations for consumers who may have consumed the recalled ice cream flavor?'},
#  {'id': 381,
#   'q1': 'What is the specific reason for the recall of Candy Blast 10oz cups by Wonder Ice Cream Company in 2009?',
#   'q2': 'Is it true that the recalled product was ice cream and not another type of dessert?',
#   'q3': 'Can you confirm if Salmonella was indeed the hazard found in the recalled product?',
#   'q4': 'How many ounces is a typical cup of ice cream, and does this size match the recalled Candy Blast cups?',
#   'q5': 'Are there any updates on whether the recall was successful in preventing further cases of salmonellosis?'},
#  {'id': 382,
#   'q1': 'What is the specific product that was recalled due to possible salmonella contamination?',
#   'q2': 'Is it true that ice cream was involved in a recall related to biological hazards?',
#   'q3': 'Can you provide more information about the Turner Holdings company and their role in this recall?',
#   'q4': 'Were there any reported cases of illness or hospitalization associated with consuming the contaminated peanut butter bars?',
#   'q5': 'What steps can consumers take to minimize their risk of exposure to salmonella when purchasing ices and desserts?'},
#  {'id': 383,
#   'q1': 'What is the specific type of ice cream that was recalled due to possible salmonella contamination?',
#   'q2': 'Was the recall initiated by Hiland Dairy Foods Company, LLC or was it a voluntary action?',
#   'q3': 'Can you provide more information about the potential health risks associated with consuming contaminated ice cream from this company?',
#   'q4': 'Did the recall affect only a specific production date range or batch of ice cream, or was it a broader recall?',
#   'q5': 'Are there any updates on whether the source of the salmonella contamination has been identified and addressed by Hiland Dairy Foods Company, LLC?'},
#  {'id': 384,
#   'q1': 'What is the specific product name that was recalled due to possible salmonella contamination?',
#   'q2': 'Is it true that Fieldbrook Foods Corporation initiated a nationwide voluntary recall of these ice cream products?',
#   'q3': 'Can you confirm if the hazard category for this incident is indeed biological, as stated in the record?',
#   'q4': 'Were any other food categories affected by this recall, aside from ices and desserts?',
#   'q5': "What was the reason behind the company's decision to initiate a voluntary recall, rather than a mandatory one?"},
#  {'id': 385,
#   'q1': 'What was the specific reason for the recall of Breyers Tin Roof Sundae Ice Cream products?',
#   'q2': 'Were any illnesses or deaths reported due to the salmonella contamination in these ice cream products?',
#   'q3': 'Can I still consume ice cream products that were manufactured before this incident, even if they are from a different brand?',
#   'q4': 'How can I identify whether my ice cream product is affected by this recall?',
#   'q5': 'Are there any similar recalls of ice cream products with peanuts due to salmonella contamination in the past?'},
#  {'id': 386,
#   'q1': 'What is the specific product that was recalled due to possible salmonella contamination?',
#   'q2': "Is it true that Rich's Nutty Sundae Cone was voluntarily recalled across multiple states?",
#   'q3': 'Can you provide more information about the biological hazard (salmonella) associated with this recall?',
#   'q4': 'Was the ice cream product category affected by this recall, or just a specific dessert item?',
#   'q5': 'What year did Rich Ice Cream Company, Inc. issue this voluntary recall?'},
#  {'id': 387,
#   'q1': 'What is the specific product that was recalled due to possible salmonella contamination?',
#   'q2': 'Is it true that Hershey Creamery announced a voluntary recall of this product?',
#   'q3': 'Can you provide more information about the hazard category associated with this incident (biological)?',
#   'q4': 'What type of product was affected by this recall (ices and desserts, ice cream, etc.)?',
#   'q5': 'Are there any other incidents involving salmonella contamination in the same year (2009) that I should be aware of?'},
#  {'id': 388,
#   'q1': 'What is the specific type of ice cream that was recalled by Belfonte Ice Cream and Dairy Foods Co.?',
#   'q2': 'Is it confirmed that the salmonella contamination occurred during production or distribution?',
#   'q3': 'Were there any reported cases of illness related to consuming the contaminated ice cream?',
#   'q4': 'Did the recall affect only a specific batch number or all products with the same product code?',
#   'q5': 'What measures did Belfonte Ice Cream and Dairy Foods Co. take to prevent similar incidents in the future?'},
#  {'id': 389,
#   'q1': "What is the specific reason for the recall of Garber's Ice Cream Company's Half Gallon Tin Roof Sundae Ice Cream and Nutty Cones?",
#   'q2': 'Is it confirmed that the recalled ice cream products contain Salmonella bacteria?',
#   'q3': 'Can you provide more information about the Peanut Corporation of America (PCA) expanded peanut recall that led to this voluntary recall?',
#   'q4': 'What are the potential health risks associated with consuming the recalled Half Gallon Tin Roof Sundae Ice Cream and Nutty Cones?',
#   'q5': "Are there any other ice cream products from Garber's Ice Cream Company that may be affected by this recall?"},
#  {'id': 390,
#   'q1': "What is the specific product code or batch number of the affected 'Chocolate Peanut Butter Delight' ice cream?",
#   'q2': 'How many containers of the recalled ice cream were sold to consumers before the recall was issued?',
#   'q3': 'Is there any information on whether the salmonella contamination was detected in-house by Mooresville Ice Cream Co. or reported by a third-party?',
#   'q4': 'What are the recommended steps for consumers who may have purchased and consumed the affected ice cream?',
#   'q5': 'Has the FDA or other regulatory agencies taken any enforcement actions against Mooresville Ice Cream Co. as a result of this recall?'},
#  {'id': 391,
#   'q1': 'What is the nature of the fraud reported for the Naturally Good, Deliciously Free—Moist Chocolate Mudcake mix?',
#   'q2': 'Is there any information available about the company or entity responsible for creating and distributing this product?',
#   'q3': 'Can you provide more details on how the labelling/misdescription hazard was identified in this incident?',
#   'q4': "What are the potential health risks associated with consuming a product that has been mislabelled as 'Naturally Good, Deliciously Free'?",
#   'q5': 'Are there any similar incidents of fraud or labelling issues reported for other products within the cereals and bakery products category?'},
#  {'id': 392,
#   'q1': 'What was the specific ice cream product recalled by Bliss Bros. Dairy, Inc.?',
#   'q2': 'How did the company become aware of the possible health risk associated with their ice cream products?',
#   'q3': 'Were any illnesses or deaths reported as a result of consuming the contaminated ice cream?',
#   'q4': 'What steps did Bliss Bros. Dairy, Inc. take to prevent similar incidents in the future?',
#   'q5': 'Is it still safe for consumers to purchase and consume ice cream from this company?'},
#  {'id': 393,
#   'q1': 'What is the specific ice cream product that has been recalled due to possible salmonella contamination?',
#   'q2': 'Are there any other types of products (e.g. dairy, meat) that have been recalled in addition to ice cream?',
#   'q3': "Can you provide more information about the 'possible health risk' mentioned in the recall notice?",
#   'q4': 'What is the scope of the recall - are all Deluxe Ice Cream Co. products being pulled from shelves or just specific codes?',
#   'q5': 'Has there been any reported illness or outbreak associated with this salmonella contamination?'},
#  {'id': 394,
#   'q1': 'What is the nature of the labelling/misdescription hazard found in A. Clouet Pty Ltd—Ayam Thai Massaman Curry, Cooking Sauce?',
#   'q2': "How does the product category 'soups, broths, sauces and condiments' relate to the type of hazard identified?",
#   'q3': 'Can you provide more information about the specific cooking sauce product that was involved in this incident?',
#   'q4': 'What are the potential consequences for consumers who may have been misled by the labelling/misdescription on A. Clouet Pty Ltd—Ayam Thai Massaman Curry, Cooking Sauce?',
#   'q5': 'Are there any similar incidents of labelling/misdescription hazards reported for other products within the same category as Ayam Thai Massaman Curry, Cooking Sauce?'},
#  {'id': 395,
#   'q1': 'What is the nature of the biological hazard involved in this recall?',
#   'q2': 'Are cookies a high-risk product for salmonella contamination?',
#   'q3': 'Can you provide more information about Glutenfreeda Foods, Inc. and their manufacturing practices?',
#   'q4': 'How did the manufacturer become aware of the possible health risk associated with Peanut Envy Frozen Cookie Dough?',
#   'q5': 'What steps can consumers take to minimize their exposure to salmonella from recalled cookie products?'},
#  {'id': 396,
#   'q1': 'What is the specific product that was recalled by Rich Ice Cream Company?',
#   'q2': 'Is there a connection between the ice cream and the candy bar avalanche products being recalled?',
#   'q3': 'How many states were initially involved in this recall before it was expanded to multiple states?',
#   'q4': 'What type of hazard was identified as the cause of this recall, and how does it relate to the product category?',
#   'q5': 'Are there any updates on whether the source of the salmonella contamination has been identified or addressed?'},
#  {'id': 397,
#   'q1': 'What is the specific ice cream product that was recalled by Schwan?',
#   'q2': 'Is there a confirmed case of salmonella illness linked to this recall?',
#   'q3': 'Can I still consume ice cream products from Schwan if they were manufactured after the recall date?',
#   'q4': 'How long did it take for Schwan to expand their initial voluntary recall to include all potentially contaminated ice cream products?',
#   'q5': 'Are there any similar recalls or incidents involving ice cream products and salmonella in the past 5 years?'},
#  {'id': 398,
#   'q1': 'What is the nature of the biological hazard (salmonella) found in the Ultimate Chunk Ice Cream?',
#   'q2': "Is there any information available about the recall process initiated by BIC Acquisition, LLC for World Classic Trading Company's product?",
#   'q3': "Can you provide more details on the product category 'ices and desserts' and how it relates to this incident?",
#   'q4': 'What are the potential health risks associated with consuming ice cream contaminated with salmonella?',
#   'q5': 'Are there any similar incidents of salmonella contamination in ice cream products reported in the same year (2009) or subsequent years?'},
#  {'id': 399,
#   'q1': 'What was the reason for expanding the voluntary recall to include ice cream?',
#   'q2': 'Is salmonella a common hazard associated with ice cream products?',
#   'q3': 'Did Turkey Hill Dairy report any illnesses or hospitalizations related to this incident?',
#   'q4': 'Can I see a list of all the products recalled by Turkey Hill Dairy in 2009?',
#   'q5': 'What was the total quantity of ice cream affected by the recall?'}]

# %%
final_results = []

for entry in results:
    doc_id=entry["id"]
    final_results.append((doc_id, entry["q1"].strip('"')))
    final_results.append((doc_id, entry["q2"].strip('"')))
    final_results.append((doc_id, entry["q3"].strip('"')))
    final_results.append((doc_id, entry["q4"].strip('"')))
    final_results.append((doc_id, entry["q5"].strip('"')))

# %%
final_results[0]
# Out:
# (300,
#  'What type of other hazard was associated with the recalled Angus beef product?')

# %%
df_results = pd.DataFrame(final_results, columns=["id", "question"])

# %%
df_results.to_csv('../data/ground-truth-retrieval_300.tsv', sep="\t", index=False)
