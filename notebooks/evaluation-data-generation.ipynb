# %%
import pandas as pd

# %% [markdown]
# # Retrieval evaluation

# %%
df = pd.read_csv("../data/incidents_train.csv", index_col=False, dtype=str)
df = df.rename(columns={"Unnamed: 0": "id", "hazard-category": "hazard_category", "product-category": "product_category"})
documents = df.to_dict(orient="records")

# %%
from openai import OpenAI

client = OpenAI(
    base_url='http://localhost:11434/v1/',
    api_key='ollama',
)

# %%
documents[0]
# Out:
# {'id': '0',
#  'year': '1994',
#  'month': '1',
#  'day': '7',
#  'country': 'us',
#  'title': 'Recall Notification: FSIS-024-94',
#  'text': "Case Number: 024-94   \n            Date Opened: 07/01/1994   \n            Date Closed: 09/22/1994 \n    \n            Recall Class:  1   \n            Press Release (Y/N):  Y  \n    \n            Domestic Est. Number:  05893  P   \n              Name:  GERHARD'S NAPA VALLEY SAUSAGE\n    \n            Imported Product (Y/N):  N       \n            Foreign Estab. Number:  N/A\n    \n            City:  NAPA    \n            State:  CA   \n            Country:  USA\n    \n            Product:  SMOKED CHICKEN SAUSAGE\n    \n            Problem:  BACTERIA   \n            Description: LISTERIA\n    \n            Total Pounds Recalled:  2,894   \n            Pounds Recovered:  2,894",
#  'hazard_category': 'biological',
#  'product_category': 'meat, egg and dairy products',
#  'hazard': 'listeria monocytogenes',
#  'product': 'smoked sausage'}

# %%
prompt_template = """
You emulate a user of a food hazard detection application.
Formulate 5 questions this user might ask based on a food-incident record. 
Make the questions specific to this record.

The record:

'title': {title}
'hazard_category': {hazard_category}
'product_category': {product_category}
'hazard': {hazard}
'product': {product}

Provide the output in parsable JSON based on the following schema:

{{"questions": ["question1", "question2", ..., "question5"]}}
""".strip()

# %%
def generate_questions(doc):
    prompt = prompt_template.format(**doc)
    response = client.chat.completions.create(
        model='llama3.1',
        messages=[{"role": "user", "content": prompt}],
        temperature=0.2
    )

    return response.choices[0].message.content

# %%
from tqdm.auto import tqdm

# %%
import json

# %%
results = {}

# %%
for doc in tqdm(documents[240:300]): 
    doc_id = doc['id']
    if doc_id in results:
        continue

    questions_raw = generate_questions(doc)
    questions = json.loads(questions_raw.split("```")[1].lstrip("json"))['questions']
    q_from_dict = []
    for q in questions:
        if isinstance(q, dict):
            if q['text']:
                q_from_dict.append(q['text'])

    with open("../data/generated_questions_100_2.tsv", "a+") as myfile:
        if len(q_from_dict)>0:
            myfile.write("\t".join([doc_id, "\t".join(q_from_dict)]))
        else:
            myfile.write("\t".join([doc_id, "\t".join(questions)]))
        myfile.write("\n")
    results[doc_id] = questions_raw
# Out:
#   0%|          | 0/60 [00:00<?, ?it/s]

# %%
df_final = pd.read_csv("../data/generated_questions_100_2.tsv", delimiter="\t", names=["id","q1","q2","q3","q4","q5"], header=None)

# %%
df_final.head()
# Out:
#     id                                                 q1  \
# 0  200  What is the nature of the hazard found in the ...
# 1  201  What is the nature of the allergen hazard asso...
# 2  202  What is the nature of the hazard identified in...
# 3  203  What is the specific type of heavy metal conta...
# 4  204  What is Sudan 4 and what makes it a chemical h...
#
#                                                   q2  \
# 0  Are there any other products from Pork Farms t...
# 1  Are eggs and products thereof commonly used as...
# 2  How does the presence of eggs in milk chocolat...
# 3  Is there any information available about the s...
# 4  Is palm oil commonly used in food products tha...
#
#                                                   q3  \
# 0  How many glass fragments were detected in the ...
# 1  Has Confectionery Trading Company recalled any...
# 2  Is there any information on the quantity of co...
# 3  Has any recall been initiated for this product...
# 4  Can you provide more information about the una...
#
#                                                   q4  \
# 0  Were the affected products distributed only wi...
# 1  Can consumers who are allergic to eggs safely ...
# 2  Were any recalls issued as a result of this in...
# 3  Are there any similar incidents reported invol...
# 4  How does this incident affect the safety of ot...
#
#                                                   q5
# 0  What is the estimated cost of the product with...
# 1  What steps can I take to inform customers abou...
# 2  What steps can I take to ensure compliance wit...
# 3  What are the potential health risks associated...
# 4  What are the next steps for recalling or re-la...

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      102 non-null    int64
#  1   q1      102 non-null    object
#  2   q2      102 non-null    object
#  3   q3      102 non-null    object
#  4   q4      102 non-null    object
#  5   q5      102 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 4.9+ KB

# %%
results = df_final.to_dict(orient='records')

# %%
results
# Out:
# [{'id': 200,
#   'q1': 'What is the nature of the hazard found in the Scotch eggs and Savoury Bites products?',
#   'q2': 'Are there any other products from Pork Farms that have been recalled due to foreign bodies?',
#   'q3': 'How many glass fragments were detected in the affected batches of Precooked cooked pork meat products?',
#   'q4': 'Were the affected products distributed only within the UK or also internationally?',
#   'q5': 'What is the estimated cost of the product withdrawal and recall for Marks and Spencer and Somerfield?'},
#  {'id': 201,
#   'q1': 'What is the nature of the allergen hazard associated with Fabulously Fun Lolly Pops?',
#   'q2': 'Are eggs and products thereof commonly used as ingredients in confectionery products like lollipops?',
#   'q3': 'Has Confectionery Trading Company recalled any other products due to similar allergen hazards?',
#   'q4': 'Can consumers who are allergic to eggs safely consume Fabulously Fun Lolly Pops?',
#   'q5': 'What steps can I take to inform customers about the egg allergen hazard in these lollipops?'},
#  {'id': 202,
#   'q1': 'What is the nature of the hazard identified in this incident (eggs and products thereof)?',
#   'q2': 'How does the presence of eggs in milk chocolate affect consumers with egg allergies?',
#   'q3': 'Is there any information on the quantity of contaminated product that was produced or distributed?',
#   'q4': 'Were any recalls issued as a result of this incident, and if so, what were their details?',
#   'q5': 'What steps can I take to ensure compliance with food safety regulations regarding allergens in chocolate products?'},
#  {'id': 203,
#   'q1': 'What is the specific type of heavy metal contaminant found in the White Wings—Cornflour 300 G product?',
#   'q2': 'Is there any information available about the source or origin of the contaminated corn used to produce this product?',
#   'q3': 'Has any recall been initiated for this product due to the heavy metals contamination?',
#   'q4': 'Are there any similar incidents reported involving other products made from corn or cereals and bakery products?',
#   'q5': 'What are the potential health risks associated with consuming White Wings—Cornflour 300 G contaminated with heavy metals?'},
#  {'id': 204,
#   'q1': 'What is Sudan 4 and what makes it a chemical hazard?',
#   'q2': 'Is palm oil commonly used in food products that I consume regularly?',
#   'q3': 'Can you provide more information about the unauthorized use of Sudan 4 in this product?',
#   'q4': 'How does this incident affect the safety of other fats and oils on the market?',
#   'q5': 'What are the next steps for recalling or re-labeling affected products containing palm oil?'},
#  {'id': 205,
#   'q1': 'What is the estimated number of glass fragments found in the affected product?',
#   'q2': 'Has Conga Foods Pty Ltd issued a recall notice for the Spanish Black Pitted Olives with the specific batch number associated with this incident?',
#   'q3': 'Can you provide more information about the Green Valley facility where the contaminated olives were produced?',
#   'q4': 'What is the typical manufacturing process for glass jars used to package the Spanish Black Pitted Olives, and could it have contributed to the presence of a glass fragment?',
#   'q5': 'Are there any similar incidents reported involving glass fragments in other products manufactured by Conga Foods Pty Ltd?'},
#  {'id': 206,
#   'q1': "What is the current status of the recall for F Mayer Imports Pty Ltd's Smoked Salmon product?",
#   'q2': 'Are there any similar incidents involving Listeria monocytogenes in smoked seafood products?',
#   'q3': 'Has the Australian government taken any measures to prevent future contamination of smoked salmon products?',
#   'q4': 'Can I get a list of all food products recalled due to Listeria monocytogenes contamination since 2020?',
#   'q5': 'What are the typical symptoms of Listeria monocytogenes infection in humans, and how is it treated?'},
#  {'id': 207,
#   'q1': 'What is the nature of the fraud alleged in this incident?',
#   'q2': 'Was there any misdescription or misleading labelling on the packaging of these Mini Beef Ravioli in Tomato Sauce products?',
#   'q3': "Can you provide more information about the product category 'prepared dishes and snacks' and how it relates to this incident?",
#   'q4': 'What specific actions did Hormel Foods Australia Pty Ltd take in response to this alleged fraud?',
#   'q5': 'Are there any similar incidents involving Hormel Foods or their products that I should be aware of?'},
#  {'id': 208,
#   'q1': 'What was the nature of the labelling/misdescription issue with the Fruity Muesli Cookies?',
#   'q2': 'Did Woolworths Limited recall any batches of the affected product?',
#   'q3': 'Were there any reported cases of consumer illness or injury related to consuming the mislabelled cookies?',
#   'q4': 'Can I see a copy of the original label that was used on the Fruity Muesli Cookies?',
#   'q5': 'Has Woolworths Limited taken any steps to prevent similar incidents from happening in the future?'},
#  {'id': 209,
#   'q1': 'What is the toxin that was detected in the Homebrand Mackerel in Natural Oil product?',
#   'q2': 'Is there a risk of food poisoning associated with consuming this product?',
#   'q3': 'Has Woolworths Limited issued any recalls or warnings related to this incident?',
#   'q4': 'What is the recommended safe handling and storage procedure for Mackerel in Natural Oil products to prevent toxin contamination?',
#   'q5': 'Are there any similar incidents of toxin contamination reported in other seafood products from Woolworths Limited or Homebrand?'},
#  {'id': 210,
#   'q1': 'What is the specific product description of the deli cooked lamb that was recalled?',
#   'q2': 'Are there any reported cases of salmonella illness associated with this recall?',
#   'q3': 'Has WM Morrison taken steps to sanitize their instore delicatessen counters and equipment?',
#   'q4': 'Is the recall limited to a specific geographic area or all locations where the product was sold?',
#   'q5': 'What is the estimated quantity of affected product that has been recalled by WM Morrison?'},
#  {'id': 211,
#   'q1': "What is the specific date range during which the contaminated ham was sold from Sainsbury's delicatessen counters?",
#   'q2': 'Are there any other products or brands that have been recalled due to salmonella contamination in the past year?',
#   'q3': 'Can I get a list of all the stores where this contaminated ham was sold, and are they located in a specific region?',
#   'q4': 'What is the recommended course of action for consumers who may have purchased this product and are concerned about food safety?',
#   'q5': "Is there any information available on how Sainsbury's plans to prevent similar incidents from happening in the future?"},
#  {'id': 212,
#   'q1': 'What is the nature of the plastic fragment found in the Maggi Frozen Macaroni Cheese?',
#   'q2': 'Was the product recalled by Nestlé due to this incident?',
#   'q3': 'Can you provide more information about the preparation and cooking instructions for this ready-to-eat meal?',
#   'q4': 'How does a foreign body like a plastic fragment end up in a frozen food product like Maggi Frozen Macaroni Cheese?',
#   'q5': 'Are there any similar incidents of plastic fragments being found in other Nestlé products?'},
#  {'id': 213,
#   'q1': 'What is the specific allergen (peanuts) that was found in the product?',
#   'q2': 'Is it possible to identify the source of the peanuts contamination in the milk chocolate covered raisins?',
#   'q3': 'Were there any reported cases of allergic reactions or illnesses related to this incident?',
#   'q4': 'Does this recall affect other products from Candy Lane Chocolate Coated Sultanas, such as their plain sultanas or other confectionery items?',
#   'q5': "What is the current status of the product's availability in stores and online marketplaces?"},
#  {'id': 214,
#   'q1': "What is the current status of the Marks & Spencer Cheesy Spirals 'Loved by Kids' meal recall?",
#   'q2': 'Can you provide more information about the chemical hazard (chlorine) found in the product?',
#   'q3': 'Are there any similar products from Marks & Spencer that have been recalled for a chemical hazard?',
#   'q4': 'How can I be sure that my child is not affected by consuming this product, and what should I do if they have already eaten it?',
#   'q5': "Is there an investigation underway to determine how chlorine ended up in the Cheesy Spirals 'Loved by Kids' meal?"},
#  {'id': 215,
#   'q1': 'What is the nature of the allergen (milk and products thereof) found in the Seawoods Soft Flour Cake?',
#   'q2': 'How does the presence of milk and products thereof affect consumers who are lactose intolerant or have a milk allergy?',
#   'q3': 'Is there any information on the quantity of milk and products thereof used in the production of the Seawoods Soft Flour Cake?',
#   'q4': 'Can you provide more details about the FSANZ 2005/01 reference mentioned in this incident record?',
#   'q5': 'What are the potential consequences for consumers who consume the Seawoods Soft Flour Cake without being aware of the milk allergen?'},
#  {'id': 216,
#   'q1': 'What is the estimated weight range of the affected BBQ sausages?',
#   'q2': 'Are there any specific pack sizes that were found to contain plastic fragments?',
#   'q3': 'Can you provide more information about the type of plastic fragment detected in the sausage product?',
#   'q4': 'Were any other products from Coles and Bi-Lo recalled due to similar foreign body hazards?',
#   'q5': 'What is the current status of this incident, has a recall been initiated or completed?'},
#  {'id': 217,
#   'q1': 'What was the nature of the spoilage issue with the chocolate flavoured milk UHT Longlife product?',
#   'q2': 'Was the spoilage issue related to a specific batch or production run of the product?',
#   'q3': 'Did the spoilage issue affect any other products in the dairy category, aside from the chocolate flavoured milk UHT Longlife?',
#   'q4': "What was the outcome of the investigation into the spoilage incident with Parmalat Australia Ltd's product?",
#   'q5': 'Are there any similar spoilage incidents reported for other dairy products in the same production facility?'},
#  {'id': 218,
#   'q1': 'What is the specific allergenic component of eggs that was found in the Coles Parmagiana Beef Rissoles?',
#   'q2': 'Are there any other products from Coles that contain beef and have been recalled due to similar egg-related hazards?',
#   'q3': 'Can you provide more information about the production process or supply chain for the Coles Parmagiana Beef Rissoles that may have led to the presence of eggs in the product?',
#   'q4': 'Have there been any reported cases of allergic reactions or foodborne illnesses associated with consuming the Coles Parmagiana Beef Rissoles?',
#   'q5': 'What steps is Coles taking to prevent similar incidents involving egg allergens in their meat, egg and dairy products?'},
#  {'id': 219,
#   'q1': 'What is the nature of the allergen hazard in these Masterfoods Mars fundraising speckled eggs boxes?',
#   'q2': 'Are there any specific product categories within cocoa and cocoa preparations, coffee and tea that are most at risk due to this peanut contamination?',
#   'q3': 'Can you provide more information about the chocolate eggs product itself, such as its packaging or manufacturing process?',
#   'q4': 'How might this peanut hazard be mitigated in future production runs of these fundraising speckled eggs boxes?',
#   'q5': 'Are there any similar incidents involving peanuts and products thereof in other Masterfoods Mars products?'},
#  {'id': 220,
#   'q1': 'What is the current status of the product recall for Mauri brand cheese Bon Taleggio Valsassina?',
#   'q2': 'Are there any reported cases of illness associated with consumption of this contaminated cheese product?',
#   'q3': 'Has Fromagent Australia taken corrective actions to prevent future contamination incidents involving their products?',
#   'q4': 'Can you provide more information about the Listeria monocytogenes strain responsible for the contamination in this case?',
#   'q5': 'What are the recommended safe handling and storage procedures for consumers who may have purchased this contaminated cheese product?'},
#  {'id': 221,
#   'q1': 'What is the specific allergenic component of milk that was found in Uncle Tobys—Le Snak Rice Crackers?',
#   'q2': 'Are there any other products from Uncle Tobys or Le Snak that contain milk and products thereof?',
#   'q3': 'Can you provide more information about the Mild Salsa Dip served with BBQ Flavoured Le Snak Rice Crackers?',
#   'q4': 'How does this incident relate to previous recalls or alerts for Uncle Tobys or Le Snak products?',
#   'q5': 'What are the recommended steps for consumers who may have ingested the affected product and are experiencing symptoms?'},
#  {'id': 222,
#   'q1': 'What was the specific cause of spoilage in the orange juice product?',
#   'q2': 'Were there any reported cases of consumer illness or complaint related to this incident?',
#   'q3': 'Did the affected product lot undergo any quality control checks before being distributed?',
#   'q4': 'Is it possible that the spoilage was due to contamination rather than a manufacturing issue?',
#   'q5': 'What corrective actions were taken by Coles, Farmland & BI-LO to prevent similar incidents in the future?'},
#  {'id': 223,
#   'q1': 'What is the specific type of cereal containing gluten that was found in the Woolworths Home Brand Nacho Cheese Flavoured Corn Chips?',
#   'q2': 'Are there any other products from Woolworths Limited that have been recalled due to similar allergen contamination issues?',
#   'q3': 'Can you provide more information about the manufacturing process for these corn chips, as it may be relevant to understanding how the gluten contamination occurred?',
#   'q4': 'What is the current status of the recall for this product - has it been completed and are there any ongoing investigations?',
#   'q5': 'Are there any recommendations or guidelines provided by regulatory agencies (e.g. FSANZ) regarding safe handling and consumption of these corn chips?'},
#  {'id': 224,
#   'q1': "What is the current status of the recall for Tender Choice Foods(Aust) Pty Ltd's Oven Roasted Skinless Sliced Chicken products?",
#   'q2': 'Has there been a confirmed case of illness associated with consumption of this product?',
#   'q3': 'Are there any specific storage or handling instructions that consumers should follow to minimize risk?',
#   'q4': 'Can you provide more information on the Listeria monocytogenes contamination found in these chicken products?',
#   'q5': 'Have any similar incidents involving ready-to-eat cook meals been reported in Australia?'},
#  {'id': 225,
#   'q1': 'What is the nature of the plastic fragment found in the Coles Myer Ltd—Bi-Lo Shredded Lite Tasty Cheese product?',
#   'q2': 'Is there a risk assessment available for this incident to determine the potential harm caused by consuming the contaminated cheese?',
#   'q3': 'Can I view the recall notice issued by the relevant authorities as a result of this incident?',
#   'q4': 'What steps has Coles Myer Ltd taken to rectify the situation and prevent similar incidents in the future?',
#   'q5': 'Are there any other products from Coles Myer Ltd that have been recalled due to foreign bodies contamination?'},
#  {'id': 226,
#   'q1': 'What is the nature of the chemical hazard found in Pun Chun Lye Water?',
#   'q2': 'Is there any information available about the source or origin of the contamination?',
#   'q3': "Has Yuen's Market Trading Company issued any recalls or warnings related to this incident?",
#   'q4': "Can you provide more details about the 'other' hazard category assigned to this product?",
#   'q5': 'Are there any similar incidents involving bottled water products that have been reported in the past?'},
#  {'id': 227,
#   'q1': 'What is the source of the Escherichia coli (E. coli) contamination in the Aristocrat Gourmet Foods—Aristocrat and Melton Pork Pies?',
#   'q2': 'Are there any reported cases of foodborne illness associated with this product?',
#   'q3': 'Has the manufacturer, Aristocrat Gourmet Foods, issued a recall for this specific product line due to E. coli concerns?',
#   'q4': 'What is the current status of the investigation into the E. coli contamination in these pork pies?',
#   'q5': 'Can I get information on any similar food safety incidents involving prepared dishes and snacks from Aristocrat Gourmet Foods?'},
#  {'id': 228,
#   'q1': 'What is the size and shape of the plastic fragment found in the ice cream?',
#   'q2': 'Was the plastic fragment a part of the packaging or an external contaminant?',
#   'q3': 'Has Coles Myer Ltd taken any corrective actions to prevent similar incidents in the future?',
#   'q4': 'Can I get more information about the production date and batch number of the affected ice cream product?',
#   'q5': "Are there any other reports of foreign bodies found in Coles Myer Ltd's ice cream products?"},
#  {'id': 229,
#   'q1': 'What is the nature of the foreign body found in the Coles Garden Vegetable Pasta Sauce?',
#   'q2': 'Is there a risk of glass fragments causing physical harm if ingested with pasta?',
#   'q3': 'Has this incident been reported to any regulatory agencies, such as the FDA or FSANZ?',
#   'q4': 'Are there any similar incidents of glass fragments being found in pasta products from other manufacturers?',
#   'q5': 'What steps can I take to minimize the risk of consuming glass fragments when eating pasta?'},
#  {'id': 230,
#   'q1': 'What is the nature of the biological hazard detected in the Lion Globe Dry Seaweed 50g product from Wei Wah International Trading Pty Ltd?',
#   'q2': 'Is it possible that the algae product was contaminated with salmonella due to improper handling or storage during transportation?',
#   'q3': 'Can you provide more information about the specific strain of salmonella found in the Lion Globe Dry Seaweed 50g product?',
#   'q4': 'How does this incident affect the overall safety and quality of other products from Wei Wah International Trading Pty Ltd?',
#   'q5': 'Are there any similar incidents involving dry seaweed or algae products that have been reported in the past?'},
#  {'id': 231,
#   'q1': 'What is the chemical hazard that was detected in the Masterfoods Mars and Snickers Bars?',
#   'q2': 'Are there any similar incidents of chemical hazards in chocolate bars reported previously?',
#   'q3': 'Has Masterfoods taken corrective actions to prevent future occurrences of this chemical hazard?',
#   'q4': 'Can I see a list of all products from Masterfoods that have been recalled due to chemical hazards?',
#   'q5': 'What are the potential health risks associated with consuming these contaminated chocolate bars?'},
#  {'id': 232,
#   'q1': 'What was the nature of the biological hazard found in Coles—Farmland Natural Spring Water?',
#   'q2': 'Was there any information provided about the source or origin of the contaminated spring water?',
#   'q3': 'Did the incident involve a recall of the product, and if so, what were the affected areas?',
#   'q4': 'Were there any reported cases of illness or adverse reactions associated with consuming this product?',
#   'q5': "Is there any additional information available about the 'other' hazard category mentioned in this record?"},
#  {'id': 233,
#   'q1': 'What is the specific reason for the presence of peanuts and products thereof in Atkins Advantage Chocolate Decadence Bars?',
#   'q2': 'Are there any other allergens present in these chocolate bars that I should be aware of?',
#   'q3': "Can you provide more information about the product category 'cocoa and cocoa preparations, coffee and tea' and how it relates to this incident?",
#   'q4': 'What are the potential health risks associated with consuming peanuts and products thereof in chocolate bars like Atkins Advantage Chocolate Decadence Bars?',
#   'q5': 'Are there any similar incidents involving Manassen Foods Australia Pty Ltd or their products that I should be aware of?'},
#  {'id': 234,
#   'q1': 'What is the nature of the allergen hazard identified in the Hello Bee Bee Pon Rice Snack?',
#   'q2': 'Is there a risk of cross-contamination with peanuts or peanut products in the production process of this rice snack?',
#   'q3': 'What is the recommended course of action for consumers who have already consumed Hello Bee Bee Pon Rice Snack and are allergic to peanuts?',
#   'q4': 'Has there been any recall or product withdrawal issued by regulatory authorities in response to this incident?',
#   'q5': 'What measures can be taken by the manufacturer, Vihenthi Co Pty Ltd, to prevent similar incidents involving allergens in their products in the future?'},
#  {'id': 235,
#   'q1': 'What type of chemical hazard was detected in the Skinny Milk product?',
#   'q2': 'Is it true that the affected product is a milk-based item, and if so, what specific type of dairy product is it?',
#   'q3': "Can you provide more information about the 'other not classified chemical hazards' mentioned in this incident record?",
#   'q4': 'Was there any recall or action taken by Parmalat Foods Australia Pty Ltd as a result of this incident?',
#   'q5': 'Are there any similar incidents involving milk products and chemical hazards in the database that I can review?'},
#  {'id': 236,
#   'q1': 'What is the nature of the chemical hazard found in the Pun Chen Lye Water product?',
#   'q2': 'Is there any information available about the source or origin of the contamination in the bottled water?',
#   'q3': 'Has Hong Australia Corp Pty Ltd taken any corrective actions to address this incident and ensure the safety of their products?',
#   'q4': 'Are there any similar incidents reported involving the same company or product category (non-alcoholic beverages) that I should be aware of?',
#   'q5': 'Can you provide more details about the regulatory agency responsible for investigating this incident and what actions they have taken?'},
#  {'id': 237,
#   'q1': "What is the nature of the 'other not classified biological hazards' found in the Angelakis Brothers—Pacific Red—Frozen Whole Cooked Vannamei Prawn?",
#   'q2': 'Is there any information on how the prawns were handled and stored before the incident to determine if that contributed to the hazard?',
#   'q3': 'Were any recalls issued for this specific product or batch, and if so, what was the scope of the recall?',
#   'q4': 'Can you provide more context about the Angelakis Brothers company, such as their reputation in the industry and compliance history?',
#   'q5': 'Are there similar incidents involving frozen seafood products that have been reported to your application?'},
#  {'id': 238,
#   'q1': 'What is the current status of the recall for these tofu products?',
#   'q2': 'Are there any reported cases of illness associated with consuming these contaminated tofu products?',
#   'q3': 'Can you provide more information about the Escherichia coli (E. coli) strain involved in this incident?',
#   'q4': 'Have any of the affected tofu products been distributed to schools or other high-risk settings?',
#   'q5': 'Is there a risk assessment available for consumers who have already purchased and consumed these contaminated tofu products?'},
#  {'id': 239,
#   'q1': 'What was the nature of the taste disturbance reported for the raw milk product?',
#   'q2': 'Were there any other products from Parmalat Foods Australia Pty Ltd. that were affected by this incident?',
#   'q3': 'Can you provide more information about the organoleptic aspects of the hazard?',
#   'q4': 'Was the raw milk product recalled due to this incident, and if so, what was the scope of the recall?',
#   'q5': 'Are there any similar incidents reported for other dairy products or companies in Australia?'},
#  {'id': 240,
#   'q1': 'What type of toxin was detected in the Trata Brand Anchovy Fillets in Sunflower Oil?',
#   'q2': 'Was there a recall issued for this product due to the chemical hazard?',
#   'q3': 'Can you provide more information about Marco Polo Foods Pty Ltd, the company responsible for producing this contaminated product?',
#   'q4': 'What is the typical shelf life of anchovies in oil, and could the toxin have been present due to improper storage or handling?',
#   'q5': 'Are there any similar incidents involving seafood products contaminated with toxins that I should be aware of?'},
#  {'id': 241,
#   'q1': 'What is the current status of the recall for Pavlova Pantry—Lamingtons?',
#   'q2': 'Has there been any update on the root cause analysis for the Listeria monocytogenes contamination in cakes?',
#   'q3': 'Can you provide more information about the product categories that are most commonly associated with Listeria monocytogenes outbreaks?',
#   'q4': 'Are there any similar incidents of Listeria monocytogenes contamination in cereals and bakery products reported in other countries?',
#   'q5': 'What is the typical shelf life for Lamingtons to ensure they remain safe from Listeria monocytogenes contamination?'},
#  {'id': 240,
#   'q1': "What is the nature of the chemical toxin found in Marco Polo Foods Pty Ltd's Trata Brand Anchovy Fillets in Sunflower Oil?",
#   'q2': 'Is there any information available on how the anchovies were processed and stored before being packaged in sunflower oil?',
#   'q3': 'Has there been a recall issued for this product by regulatory authorities, such as FSANZ or local health departments?',
#   'q4': 'What are the potential health risks associated with consuming Trata Brand Anchovy Fillets in Sunflower Oil contaminated with toxin?',
#   'q5': 'Are there any similar incidents of chemical contamination reported in seafood products packaged in sunflower oil?'},
#  {'id': 241,
#   'q1': 'What is the current status of the recall for Pavlova Pantry—Lamingtons?',
#   'q2': 'Are there any reported cases of illness associated with consuming Lamingtons contaminated with Listeria monocytogenes?',
#   'q3': 'Has the manufacturer, Pavlova Pantry, implemented corrective actions to prevent future contamination incidents?',
#   'q4': 'What are the recommended storage and handling procedures for cakes that may have been exposed to the recalled Lamingtons?',
#   'q5': 'Can I get a list of all products that were manufactured in the same facility as the contaminated Lamingtons?'},
#  {'id': 242,
#   'q1': 'What type of biological hazard was detected in the Aroy-D Mussaman curry soup product?',
#   'q2': 'Is it possible that the other not classified biological hazards were introduced during the cooking process for ready to eat meals?',
#   'q3': 'Can you provide more information about the T & D Trading Co Pty Ltd company and their food safety practices?',
#   'q4': 'What steps have been taken by regulatory authorities to investigate and address this incident?',
#   'q5': 'Are there any similar incidents of other not classified biological hazards in prepared dishes and snacks products?'},
#  {'id': 243,
#   'q1': 'What is the nature of the plastic fragment found in the Vogels Fruit and Nut Bread from Gold Coast Bakery Queensland Pty Ltd?',
#   'q2': 'Has there been any previous incident reports involving foreign bodies in cereals and bakery products from this manufacturer?',
#   'q3': 'Can you provide more information about the batch number or production date of the affected bread product?',
#   'q4': 'What is the current status of the investigation into this incident, and are any recalls or warnings issued to consumers?',
#   'q5': 'Are there any similar incidents reported involving Vogels Fruit and Nut Bread or other products from Gold Coast Bakery Queensland Pty Ltd?'},
#  {'id': 244,
#   'q1': "What is the nature of the 'other not classified biological hazards' found in Loong Heed Instant Tai Pla Paste?",
#   'q2': 'Is it possible that consumers who have already purchased and consumed this product may be at risk of foodborne illness?',
#   'q3': 'Can you provide more information about the company, T & D Trading Co Pty Ltd, including their address and contact details?',
#   'q4': "What are the typical symptoms of food poisoning caused by 'other not classified biological hazards' in ready-to-eat cooked meals like Loong Heed Instant Tai Pla Paste?",
#   'q5': 'Are there any specific guidelines or recommendations for handling and disposal of this product to prevent further contamination?'},
#  {'id': 245,
#   'q1': 'What is the nature of the hazard associated with Coles—Farmland Tropical Muesli (750g)?',
#   'q2': 'Is there a specific type of product that contains peanuts and products thereof, which could be contaminated?',
#   'q3': 'What is the typical serving size or portion of Coles—Farmland Tropical Muesli (750g) that might contain peanuts?',
#   'q4': 'Are there any other products in the cereals and bakery products category that have been recalled due to peanut contamination?',
#   'q5': 'What are the recommended steps for consumers who may have ingested Coles—Farmland Tropical Muesli (750g) containing peanuts?'},
#  {'id': 246,
#   'q1': "What is the specific reason for the presence of peanuts and products thereof in Uncle Tobys—Plus Sultanas 'n Bran?",
#   'q2': "How does the product category 'fruits and vegetables' relate to the hazard of peanuts and products thereof?",
#   'q3': 'Are there any other food products that have been recalled or involved in incidents due to similar contamination issues with raisins?',
#   'q4': "What is the typical shelf life for Uncle Tobys—Plus Sultanas 'n Bran, and could this factor into the likelihood of contamination?",
#   'q5': "Have there been any reported cases of allergic reactions or adverse health effects associated with consuming Uncle Tobys—Plus Sultanas 'n Bran?"},
#  {'id': 247,
#   'q1': "What is the exact nature of the contamination found in Marks & Spencer's own-brand cake products?",
#   'q2': 'Are there any reported cases of consumers experiencing physical harm or illness due to consuming these contaminated cakes?',
#   'q3': 'What is the estimated number of affected cake products that were sold by Marks & Spencer before the recall was issued?',
#   'q4': 'Has Marks & Spencer provided any information on how the coloured plastic strands ended up in their cake products?',
#   'q5': 'Are there any similar incidents of food contamination with foreign bodies (e.g. plastic fragments) reported for other bakery products or brands?'},
#  {'id': 248,
#   'q1': 'What was the specific reason for the recall of ham products by MO Firm on Dec 1, 2005?',
#   'q2': 'Were any other types of meat, egg and dairy products also recalled due to Listeria monocytogenes contamination?',
#   'q3': 'Can you provide more information about the Listeria monocytogenes outbreak that led to this recall?',
#   'q4': 'What were the consequences for MO Firm as a result of this food safety incident?',
#   'q5': 'Are there any similar recalls or incidents involving ham products and Listeria monocytogenes in the past?'},
#  {'id': 249,
#   'q1': "What is the current status of the recall for Conroy's Smallgoods sausage products?",
#   'q2': 'Are there any specific storage or handling instructions I should follow to prevent contamination with Listeria monocytogenes?',
#   'q3': 'Can you provide more information about the affected product categories, specifically what types of smallgoods are included in this recall?',
#   'q4': 'How can consumers identify whether they have purchased a recalled sausage product from Foodland stores?',
#   'q5': "Are there any similar incidents involving Conroy's Smallgoods or other food manufacturers that I should be aware of?"},
#  {'id': 250,
#   'q1': 'What is the nature of the labelling/misdescription issue reported for Coles—Premium Fruit Mince Pie 4 Pack?',
#   'q2': 'Was there any evidence of intentional deception or misrepresentation by the manufacturer or distributor?',
#   'q3': 'How does this incident relate to previous reports of similar issues with other products in the cereals and bakery products category?',
#   'q4': 'What steps has Coles taken to address the labelling/misdescription issue and ensure compliance with regulatory requirements?',
#   'q5': 'Are there any ongoing investigations or recalls related to this product, and if so, what are their current statuses?'},
#  {'id': 251,
#   'q1': 'What is the nature of the allergen (almond) found in the Coles Myer Limited—Farmland Tropical Muesli product?',
#   'q2': 'Is there any information available on the quantity or concentration of almond present in this muesli product?',
#   'q3': 'Can you provide details about the potential health risks associated with consuming this muesli product for individuals with almond allergies?',
#   'q4': 'Are there any similar food products from Coles Myer Limited that also contain almonds, which could pose a risk to consumers with almond allergies?',
#   'q5': 'What steps has Coles Myer Limited taken to address and rectify the issue of almond presence in their Tropical Muesli product?'},
#  {'id': 252,
#   'q1': 'What is the nature of the metal fragment found in the Bulla Dairy Foods—Bulla , Farmland & Homebrand Brand Names—Low Fat Cottage Cheese product?',
#   'q2': 'Are there any other products from the same manufacturer that have been recalled due to similar foreign body hazards?',
#   'q3': 'How does this incident affect consumers who are lactose intolerant or have dairy allergies?',
#   'q4': 'What steps is the manufacturer taking to prevent future incidents of metal fragments in their cottage cheese products?',
#   'q5': 'Has there been an investigation into how the metal fragment ended up in the product, and what measures will be taken to ensure quality control?'},
#  {'id': 253,
#   'q1': 'What is the current status of the recall for Parilla Fresh Alfalfa sprouts?',
#   'q2': 'Are there any reported cases of salmonella illness linked to consumption of Action brand Alfalfa sprouts?',
#   'q3': 'Can you provide more information about the source and origin of the contaminated alfalfa sprouts?',
#   'q4': 'How can I identify whether I have purchased or consumed contaminated alfalfa sprouts from Woolworths or Action brands?',
#   'q5': 'What are the recommended steps for consumers who may have handled or eaten contaminated alfalfa sprouts?'},
#  {'id': 254,
#   'q1': 'What is the estimated quantity of raspberries affected by the glass fragment?',
#   'q2': 'Were any consumer complaints or illnesses reported due to consumption of the contaminated raspberries?',
#   'q3': 'Has the manufacturer taken steps to recall the affected product and prevent future contamination incidents?',
#   'q4': 'Can you provide more information about the origin and handling practices that led to the presence of a glass fragment in the raspberry conserve?',
#   'q5': 'Are there any similar incidents of foreign bodies being found in fruit or vegetable products from this manufacturer?'},
#  {'id': 255,
#   'q1': "What is the correct labelling information for Marks & Spencer's own-brand 3 Bean & Spinach Salad with Chive Dressing?",
#   'q2': 'Are soybeans and products thereof a common allergen in salads like this one?',
#   'q3': 'Has there been any previous recalls of Marks & Spencer products due to incorrect labelling?',
#   'q4': 'What is the process for reporting food hazards like this incident to regulatory authorities?',
#   'q5': 'How can I, as a consumer, be sure that the salad I buy from Marks & Spencer has accurate and safe labelling?'},
#  {'id': 256,
#   'q1': 'What is the nature of the biological hazard (yeasts) found in the wine product?',
#   'q2': 'Is there any information available about the potential health risks associated with consuming this contaminated wine?',
#   'q3': 'How was the contamination by yeasts detected and reported to the authorities?',
#   'q4': 'Are there any similar incidents of yeast contamination in other wine products from Pernod Ricard Pacific Pty Ltd?',
#   'q5': 'What corrective actions have been taken or are planned by the manufacturer to prevent future occurrences of yeast contamination?'},
#  {'id': 257,
#   'q1': 'What is the current status of the recall for Parilla—Fresh and Woolworths brand Alfalfa Sprouts?',
#   'q2': 'Are there any reported cases of salmonella illness associated with consuming these alfalfa sprouts?',
#   'q3': 'Can you provide more information about the source of the contaminated alfalfa sprouts?',
#   'q4': 'How can I identify whether the alfalfa sprouts in my fridge are part of this recall?',
#   'q5': 'Have there been any updates to the product category or hazard category for this incident?'},
#  {'id': 258,
#   'q1': 'What is the current status of the recall for Country Valley—Classic Cream (minimum 35% fat) due to E. coli contamination?',
#   'q2': 'Are there any reported cases of illness associated with consuming Country Valley—Classic Cream (minimum 35% fat)?',
#   'q3': 'Can you provide more information about the production facility where Country Valley—Classic Cream (minimum 35% fat) was manufactured?',
#   'q4': 'Is it safe for consumers to consume other dairy products from the same manufacturer as Country Valley—Classic Cream (minimum 35% fat)?',
#   'q5': 'What steps has the regulatory agency taken to investigate and address the E. coli contamination in Country Valley—Classic Cream (minimum 35% fat)?'},
#  {'id': 259,
#   'q1': 'What was the size and shape of the metal fragment found in the minced pork?',
#   'q2': 'Was the metal fragment a result of a manufacturing defect or an external contamination?',
#   'q3': 'Has Woolworths Supermarkets recalled any other products from this supplier due to similar incidents?',
#   'q4': 'What steps is the regulatory agency taking to ensure that all pork mince products are thoroughly inspected for metal fragments?',
#   'q5': 'Are there any recommendations or guidelines provided by the food safety authorities for consumers on how to identify and report similar incidents in the future?'},
#  {'id': 260,
#   'q1': 'What is the nature of the foreign bodies found in Top Taste cakes?',
#   'q2': 'Were any other products from the same batch or production run also affected by the foreign body contamination?',
#   'q3': 'Has there been any previous incident of foreign body contamination with Top Taste cakes or their ingredients?',
#   'q4': 'Can you provide more information about the type of cake that was contaminated (e.g. flavor, size, packaging)?',
#   'q5': 'What is the current status of the product recall and removal from store shelves?'},
#  {'id': 261,
#   'q1': 'What is the current status of the recall for Tibaldi Smallgoods—Loin Capocollo mild?',
#   'q2': 'Are there any reported cases of salmonella illness associated with this product?',
#   'q3': 'Can you provide more information about the manufacturing process and handling procedures that led to the contamination?',
#   'q4': 'How does the presence of salmonella in pork fillets affect the shelf life of the product?',
#   'q5': 'Is it safe for consumers who have already consumed Tibaldi Smallgoods—Loin Capocollo mild to seek medical attention?'},
#  {'id': 262,
#   'q1': 'What is the nature of the plastic fragment found in the Farmland Apple Oven Baked Fruit Bars?',
#   'q2': 'Is there any information available about how the plastic fragment ended up in the product?',
#   'q3': 'Can you provide more details about the Coles Myer Ltd recall process for this product?',
#   'q4': 'Were any other products from Coles Myer Ltd or Farmland affected by this incident?',
#   'q5': 'What steps can consumers take to identify and report similar incidents with their own food products?'},
#  {'id': 263,
#   'q1': 'What is the current status of the recall for Buona Pasta Beef Ravioli and Ravioli Da Brodo?',
#   'q2': 'Are there any reported cases of salmonella illness associated with this product?',
#   'q3': 'Can you provide more information about the supplier, J&F Corbo Pty Ltd, and their food safety practices?',
#   'q4': 'Has the affected product been removed from sale in all states or countries where it was distributed?',
#   'q5': 'What are the recommended steps for consumers who may have purchased Buona Pasta Beef Ravioli and Ravioli Da Brodo?'},
#  {'id': 264,
#   'q1': 'What is the nature of the plastic fragment found in the ham product?',
#   'q2': 'Has Coles Myers Pty Ltd recalled any other products due to foreign bodies in the past?',
#   'q3': 'Is there a risk assessment available for this incident that I can review?',
#   'q4': 'Can you provide more information about the Savings Luncheon Ham and Chicken Meat product, such as its packaging and distribution channels?',
#   'q5': 'What steps is the regulatory agency taking to ensure that similar incidents do not occur in the future?'},
#  {'id': 265,
#   'q1': 'What is the exact nature of the metal contamination found in the Go Ahead! brand Crispy Fruit Slices and Yoghurt Breaks?',
#   'q2': 'Are there any reported cases of consumers actually finding metal fragments in their purchased products?',
#   'q3': 'Can you provide more information on the batches of Go Ahead! brand Crispy Fruit Slices and Yoghurt Breaks that are being recalled?',
#   'q4': 'Is United Biscuits taking any additional steps to ensure the quality control of its confectionery products, aside from this recall?',
#   'q5': 'How can consumers who have purchased affected products get in touch with United Biscuits or a relevant authority for assistance?'},
#  {'id': 266,
#   'q1': 'What is the nature of the microbiological contamination found in the Always Fresh Baby Clams?',
#   'q2': 'Are there any similar incidents reported for Riviana Foods Pty Ltd or their Always Fresh brand?',
#   'q3': 'How does this incident affect the overall safety and quality of clams as a seafood product category?',
#   'q4': 'Can you provide more information about the tin can packaging used for the 200g Always Fresh Baby Clams, considering its potential role in the contamination?',
#   'q5': 'What are the recommended steps for consumers who may have purchased or consumed the contaminated Always Fresh Baby Clams?'},
#  {'id': 267,
#   'q1': 'What was the specific reason for recalling cheese sausages on May 25, 2006?',
#   'q2': 'Are there any other products that contain milk and its by-products which were also recalled on this date?',
#   'q3': 'Can you provide more information about the firm that initiated the recall of cheese sausages?',
#   'q4': 'Were there any reported cases of allergic reactions or illnesses related to consuming these cheese sausages?',
#   'q5': 'Is it possible to view a list of all products and firms involved in recalls due to allergens on this date?'},
#  {'id': 268,
#   'q1': "What is the current status of the recall for Darling Downs Foods Pty Ltd's Selected KR Castlemaine products?",
#   'q2': 'Are there any reported cases of enterovirus illness associated with consuming ham from Darling Downs Foods Pty Ltd?',
#   'q3': 'Can you provide more information on the potential health risks associated with enteroviruses in meat products like ham?',
#   'q4': 'Has Darling Downs Foods Pty Ltd taken corrective actions to prevent future contamination incidents involving enteroviruses?',
#   'q5': 'Are there any similar food safety incidents reported for other companies that produce ham or other meat, egg and dairy products?'},
#  {'id': 269,
#   'q1': "What is the nature of the microbiological contamination found in McVitie's The Original Digestive biscuits?",
#   'q2': 'Is there any information available about the source of the contamination (e.g. ingredient supplier, manufacturing process)?',
#   'q3': 'Were any recalls or product withdrawals issued as a result of this incident?',
#   'q4': 'Can you provide more details on the risk assessment that was conducted to determine the severity of the hazard?',
#   'q5': 'Are there any similar incidents involving microbiological contamination in biscuits or other baked goods products?'},
#  {'id': 270,
#   'q1': 'What was the specific cause of spoilage in the Maggi Liquid Cooking Sauce?',
#   'q2': 'How did Nestlé detect the spoilage issue with their product?',
#   'q3': 'Was the spoilage related to a contamination or a manufacturing process error?',
#   'q4': 'Did the spoilage affect the taste, texture, or smell of the cooking sauce?',
#   'q5': 'Has Nestlé recalled any batches of Maggi Liquid Cooking Sauce due to this incident?'},
#  {'id': 271,
#   'q1': 'What is the nature of the fraud involved in the labelling/misdescription of Horlicks drink powder?',
#   'q2': 'How does the mislabelling of milk powder as a meat, egg and dairy product affect consumer safety?',
#   'q3': 'Was any action taken against Wah Lien Trading Pty Ltd following this incident?',
#   'q4': 'Can you provide more information about the investigation into this incident?',
#   'q5': 'What measures can consumers take to protect themselves from similar incidents in the future?'},
#  {'id': 272,
#   'q1': 'What is the nature of the metal fragment found in Sunbeam brand dried fruits?',
#   'q2': 'Are there any similar incidents reported involving Sunbeam Foods Pty Ltd or their products?',
#   'q3': 'How does this incident affect consumers who have purchased Sunbeam brand dried fruits from Angas Park?',
#   'q4': "Can you provide more information about the product category 'fruits and vegetables' and how it relates to this incident?",
#   'q5': 'What steps is Sunbeam Foods Pty Ltd taking to rectify the situation and prevent future occurrences?'},
#  {'id': 273,
#   'q1': "What is the specific allergen present in Ricky's BBQ flavoured Rice Crackers?",
#   'q2': 'Are there any other products from Australian Discount Retail that contain gluten?',
#   'q3': "Can you provide more information about the product category 'cereals and bakery products'?",
#   'q4': 'How does this incident relate to food safety regulations for allergens in Australia?',
#   'q5': "What are the potential health risks associated with consuming Ricky's BBQ flavoured Rice Crackers for individuals with celiac disease or gluten intolerance?"},
#  {'id': 274,
#   'q1': 'What is the specific allergen present in the Black & Gold Choc sultanas product?',
#   'q2': 'Is there any information available about the production date or batch number of the affected product?',
#   'q3': 'How does this incident relate to other reported cases of peanut contamination in confectionery products?',
#   'q4': 'Can I access a list of all food-incident records related to peanuts and their products?',
#   'q5': 'Are there any recalls or warnings issued by regulatory authorities as a result of this incident?'},
#  {'id': 275,
#   'q1': 'What is the exact nature of the insect infestation found in the Quaker Oats product?',
#   'q2': 'Has there been any recall or withdrawal of similar oat products from other manufacturers due to insect contamination?',
#   'q3': 'Are moth pupae and larvae considered a high-risk food hazard, and what are the potential health consequences for consumers who ingest them?',
#   'q4': 'What is the scope of the withdrawal - was it limited to specific batches, production lines, or even entire facilities?',
#   'q5': 'Has Quaker Oats Ltd taken any measures to prevent future insect infestations in their manufacturing processes?'},
#  {'id': 276,
#   'q1': 'What is the specific strain of Escherichia coli that was found in the frozen beef patties?',
#   'q2': 'Were any consumer complaints or illnesses reported as a result of consuming these recalled ground beef products?',
#   'q3': 'Can you provide more information about the firm that issued the recall, such as their company name and location?',
#   'q4': 'What is the estimated quantity of affected product that was distributed to consumers before the recall was issued?',
#   'q5': 'Are there any similar recalls or incidents involving frozen beef patties or other meat products in the past 5 years?'},
#  {'id': 277,
#   'q1': 'What is the size and shape of the glass fragment found in the pickled cucumbers?',
#   'q2': 'Was the product recalled due to this incident, and if so, what was the recall status?',
#   'q3': 'Can you provide more information about the manufacturing process that led to the presence of a glass fragment in the product?',
#   'q4': 'Were there any consumer complaints or reports related to this incident before it was detected by your application?',
#   'q5': 'How does this incident align with previous food safety incidents involving Manassen Foods Australia Pty Ltd?'},
#  {'id': 278,
#   'q1': 'What is the nature of the metal fragment found in the Nestlé Nan 2 H.A. Gold Infant Formula?',
#   'q2': 'Could the presence of a metal fragment in an infant formula product pose a risk to consumers with certain medical conditions?',
#   'q3': "Has there been any previous incident reports involving foreign bodies in Nestlé's infant formula products?",
#   'q4': 'What is the recommended course of action for parents who have fed their infants the affected product before discovering this recall notice?',
#   'q5': 'Are there any similar incidents reported in other countries involving metal fragments in infant formula products?'},
#  {'id': 279,
#   'q1': 'What was the specific type of microbiological contamination found in the milk products?',
#   'q2': 'Were any consumers reported to have fallen ill after consuming the contaminated milk products?',
#   'q3': 'Can you provide more information about the production facility where the contaminated milk products were manufactured?',
#   'q4': 'How did the contamination occur, according to the investigation report?',
#   'q5': 'Are there any similar incidents of microbiological contamination in milk products that I should be aware of?'},
#  {'id': 280,
#   'q1': 'What is the specific batch number of the affected Marks & Spencer Strawberry & Almond Crunch breakfast cereals?',
#   'q2': 'Are there any other products from Marks & Spencer that contain milk as an ingredient and may have incorrect allergy labelling?',
#   'q3': 'Has there been a recall of similar breakfast cereal products in the past due to allergen mislabelling?',
#   'q4': 'What is the process for reporting suspected food allergies or intolerances related to Marks & Spencer products?',
#   'q5': 'Are there any plans by Marks & Spencer to implement additional measures to prevent incorrect allergy labelling on their own-brand products?'},
#  {'id': 281,
#   'q1': 'What is the scope of the product recall - are all brands and products affected?',
#   'q2': 'Can you provide more information about the glass fragment found in the frozen meals?',
#   'q3': 'How did the glass contamination occur in the first place?',
#   'q4': 'Are there any specific symptoms or health risks associated with consuming these contaminated meals?',
#   'q5': 'What is the recommended course of action for consumers who may have already purchased and consumed one of the recalled products?'},
#  {'id': 282,
#   'q1': 'What type of processing hazard was identified in the recalled ready to eat - cook meals?',
#   'q2': 'Was the recall related to any specific allergen or contaminant?',
#   'q3': 'Can you provide more information about the PA Firm that issued the recall?',
#   'q4': 'Were there any reported illnesses or adverse reactions associated with the consumption of the recalled product?',
#   'q5': 'Is it safe for consumers who have already purchased and consumed the affected ready to eat - cook meals?'},
#  {'id': 283,
#   'q1': 'What was the nature of the taste disturbance reported in the Harvey Fresh Ltd—All White Milk incident?',
#   'q2': 'Was the milk product recalled due to the organoleptic aspects hazard?',
#   'q3': 'Can you provide more information about the dairy products category and how it relates to this incident?',
#   'q4': 'How common are taste disturbances as a hazard in the meat, egg and dairy products category?',
#   'q5': 'What steps can consumers take to identify and report similar taste disturbances in milk products?'},
#  {'id': 284,
#   'q1': 'What is the nature of the allergen hazard detected in the chocolate eggs produced by Kinnerton Confectionary Australia Pty Ltd?',
#   'q2': 'Are there any specific ingredients or components in the Spiderman 3 ceramic mug that may be contaminated with peanuts?',
#   'q3': 'How does this incident relate to previous recalls or alerts involving Kinnerton Confectionary Australia Pty Ltd?',
#   'q4': 'What is the recommended course of action for consumers who have purchased and consumed the affected chocolate eggs?',
#   'q5': 'Are there any plans in place by the manufacturer to reformulate or re-label their products to avoid similar allergen hazards in the future?'},
#  {'id': 285,
#   'q1': 'What is the nature of the unapproved establishment involved in distributing Moubon Yoghurt Dessert?',
#   'q2': 'Has any action been taken against the distributor or manufacturer of Moubon Yoghurt Dessert?',
#   'q3': 'What is the current status of the yoghurt product in question, and are there any recalls or withdrawals in place?',
#   'q4': 'Can you provide more information about the fraud involved in this incident, such as who was responsible or what their motivations were?',
#   'q5': 'Are there any similar incidents involving yoghurt products from unapproved establishments that I should be aware of?'},
#  {'id': 286,
#   'q1': 'What is the current status of the recall for Top of the Range brand free range eggs due to salmonella contamination?',
#   'q2': 'Are there any reported cases of illness associated with consuming these contaminated eggs?',
#   'q3': 'Can you provide more information about the Game Farm Enterprises (Qld) Pty Ltd facility where the contaminated eggs were produced?',
#   'q4': 'What steps have been taken by regulatory authorities to prevent similar incidents in the future?',
#   'q5': 'Is it safe for consumers who have already purchased Top of the Range brand free range eggs to consume them, or should they be discarded?'},
#  {'id': 287,
#   'q1': 'What were the specific heavy metals found in the bottled mineral water?',
#   'q2': 'Were there any reported cases of illness or adverse health effects associated with consuming the contaminated water?',
#   'q3': 'Can you provide more information about the recall process and how it was initiated?',
#   'q4': 'Did the affected product have a unique identifier, such as a batch number or code, that could be used to identify potentially contaminated products?',
#   'q5': 'Were there any changes made to the manufacturing process or quality control procedures at the facility responsible for producing the bottled mineral water?'},
#  {'id': 288,
#   'q1': 'What is the current status of the recall for Whitestone Windsor Blue Cheese?',
#   'q2': 'Has there been a confirmed case of illness associated with consumption of Whitestone Windsor Blue Cheese contaminated with Listeria monocytogenes?',
#   'q3': 'Is Whitestone Windsor Blue Cheese still available in stores, or has it been removed from sale due to this contamination?',
#   'q4': 'What is the recommended safe storage and handling procedure for consumers who may have purchased Whitestone Windsor Blue Cheese?',
#   'q5': 'Are there any similar products from Whitestone that may also be contaminated with Listeria monocytogenes?'},
#  {'id': 289,
#   'q1': 'What is the current status of the recall for National Foods Pty Ltd—Tilba Cheese?',
#   'q2': 'Are there any reported cases of salmonella illness associated with consuming Tilba Cheese?',
#   'q3': 'Has the manufacturer taken corrective action to prevent future contamination incidents?',
#   'q4': 'Can I get a list of countries where the affected cheese was distributed?',
#   'q5': 'What is the estimated volume of contaminated cheese that has been sold or consumed?'},
#  {'id': 290,
#   'q1': 'What types of heavy metals were detected in the bottled mineral water?',
#   'q2': 'Were there any reported cases of illness or adverse health effects associated with consuming this product?',
#   'q3': 'Can you provide more information about the recall process and how it was initiated?',
#   'q4': 'Did the affected product have a specific expiration date or batch number that triggered the recall?',
#   'q5': 'Are there any similar incidents involving bottled mineral water in other countries or regions?'},
#  {'id': 291,
#   'q1': 'What is the size and shape of the plastic fragment found in the Kit Kat Caramel & Cookie Dough cookies?',
#   'q2': "Was the plastic fragment a part of the cookie's packaging or an external contaminant?",
#   'q3': 'Has Nestlé issued any recalls or statements regarding this incident with their Kit Kat product?',
#   'q4': 'Can I get more information about how many people were affected by consuming these contaminated cookies?',
#   'q5': "Are there any similar incidents reported in the past involving foreign bodies in Nestlé's cookie products?"},
#  {'id': 292,
#   'q1': 'What is the current status of the recall for Primo Smallgoods—Shaved Chicken Breast?',
#   'q2': 'Has there been any update on the root cause analysis for the Listeria monocytogenes contamination in chicken breast products?',
#   'q3': 'Are there any similar incidents involving Listeria monocytogenes in meat, egg and dairy products that I should be aware of?',
#   'q4': 'Can you provide more information about the affected product, specifically the packaging and distribution channels used by Primo Smallgoods?',
#   'q5': 'What are the recommended corrective actions for food establishments to prevent similar contamination incidents?'},
#  {'id': 293,
#   'q1': 'What is the exact nature of the plastic fragment found in the Kit Kat Caramel & Cookie Dough cookies?',
#   'q2': 'Was the incident related to a specific production line or batch number?',
#   'q3': "Have there been any previous incidents involving foreign bodies in Nestlé's Kit Kat products?",
#   'q4': 'How does this incident align with regulatory requirements for food safety and quality control?',
#   'q5': 'What corrective actions has Nestlé taken or plans to take as a result of this incident?'},
#  {'id': 294,
#   'q1': 'What is the specific type of ham that was contaminated with Listeria monocytogenes?',
#   'q2': 'Is there a risk to consumers who have already consumed Prosciutto Parma whole legs and Serrano ham slices and whole legs?',
#   'q3': 'Can you provide more information about the source of the contamination, such as the production facility or supplier?',
#   'q4': 'Are there any similar food products that may also be at risk due to this incident?',
#   'q5': 'What are the recommended steps for consumers who have purchased Prosciutto Parma whole legs and Serrano ham slices and whole legs to ensure their safety?'},
#  {'id': 295,
#   'q1': 'What is the current status of the recall for Franklins—No Frills Pizza—Ham and Pineapple and Supreme varieties?',
#   'q2': 'Are there any reported cases of illness or adverse reactions associated with consuming this product?',
#   'q3': 'Can you provide more information about the moulds detected in the frozen pizza, such as their type and potential health risks?',
#   'q4': 'Have any corrective actions been taken by the manufacturer to prevent future contamination incidents?',
#   'q5': 'Is it safe for consumers who have already consumed this product to seek medical attention if they experience any symptoms?'},
#  {'id': 296,
#   'q1': "What is the nature of the labelling/misdescription hazard reported for Willow Confectionery's Dark Chocolate Easter Eggs?",
#   'q2': 'How does this incident relate to other reported cases of fraud in the cocoa and cocoa preparations, coffee and tea category?',
#   'q3': 'Can you provide more information about the product description that was allegedly misleading or false on the packaging of these chocolate eggs?',
#   'q4': 'What actions have been taken by regulatory authorities to address this incident and prevent similar incidents in the future?',
#   'q5': 'Are there any updates on whether Willow Confectionery has taken corrective action, such as recalling the affected products or revising their labelling practices?'},
#  {'id': 297,
#   'q1': "What is the specific labelling or misdescription issue that led to the fraud incident with The Kettle Chip Company's Chilli Potato Chips?",
#   'q2': "Can you provide more information about the product category 'prepared dishes and snacks' and how it relates to this incident?",
#   'q3': 'Is there any evidence of intentional deception by The Kettle Chip Company in their labelling or marketing practices?',
#   'q4': 'How does this incident affect consumer trust in food products with similar labelling or misdescription issues?',
#   'q5': 'Are there any regulatory actions being taken against The Kettle Chip Company as a result of this fraud incident?'},
#  {'id': 298,
#   'q1': 'What is the exact nature of the labelling/misdescription issue reported in this incident?',
#   'q2': 'Are there any other seafood products from Better Choice that have been involved in similar incidents?',
#   'q3': 'Can you provide more information about the prawns product itself, such as its origin and distribution channels?',
#   'q4': 'How does this incident relate to previous reports of mislabelling or misdescription in the seafood industry?',
#   'q5': 'What corrective actions has Better Choice taken or plans to take in response to this incident?'},
#  {'id': 299,
#   'q1': 'What is the specific strain of Escherichia coli (E. coli) that was found in the recalled Angus beef products?',
#   'q2': 'Were any consumer complaints or illnesses reported as a result of consuming these contaminated ground beef products?',
#   'q3': 'Can you provide more information about the Texas firm responsible for recalling the ground beef products, such as their company name and contact details?',
#   'q4': 'What were the exact dates during which the contaminated ground beef products were distributed to consumers, and what was the total quantity recalled?',
#   'q5': 'Are there any similar recalls or incidents involving E. coli contamination in ground beef products that have occurred since this incident?'}]

# %%
final_results = []

for entry in results:
    doc_id=entry["id"]
    final_results.append((doc_id, entry["q1"].strip('"')))
    final_results.append((doc_id, entry["q2"].strip('"')))
    final_results.append((doc_id, entry["q3"].strip('"')))
    final_results.append((doc_id, entry["q4"].strip('"')))
    final_results.append((doc_id, entry["q5"].strip('"')))

# %%
final_results[0]
# Out:
# (200,
#  'What is the nature of the hazard found in the Scotch eggs and Savoury Bites products?')

# %%
df_results = pd.DataFrame(final_results, columns=["id", "question"])

# %%
df_results.to_csv('../data/ground-truth-retrieval_100_2.tsv', sep="\t", index=False)
